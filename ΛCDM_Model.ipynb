# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitCosmo/hubble-data/blob/main/%CE%9BCDM_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import pi, log, sqrt
import getdist
import numpy as np
from io import StringIO
from getdist import plots, MCSamples
import random
from scipy.integrate import quad
from scipy.interpolate import interp1d
from scipy.integrate import odeint
import scipy.integrate as integrate
import matplotlib.pyplot as plt
from scipy import stats
import pypolychord
from pypolychord.settings import PolyChordSettings
from pypolychord.priors import UniformPrior, GaussianPrior
import scipy.optimize as op
from numpy.linalg import inv
from mpi4py import MPI
import sympy as sp
import scipy.linalg as la
import pandas as pd

# %% [markdown]
# # Cosmic Chronometers Dataset with Full Covariance
#
# **Source:** [https://gitlab.com/mmoresco/CCcovariance](https://gitlab.com/mmoresco/CCcovariance)
#
# ### Description
#
# This analysis utilizes the Cosmic Chronometers (CC) dataset with the full covariance matrix and prepares the likelihood function for cosmological parameter estimation.
#
# ### Citation Guidelines
#
# If you use this dataset, please cite the following foundational works by Prof. Dr. Moresco:
#
# - Moresco et al. (2016), [arXiv:1804.05864](https://doi.org/10.48550/arXiv.1804.05864)
# - Moresco (2020), [arXiv:2003.07362](https://doi.org/10.48550/arXiv.2003.07362)
#
# Additionally, when using the same data, please acknowledge these important references:
#
# - Simon et al. (2005), [arXiv:1201.3609](https://doi.org/10.48550/arXiv.1201.3609)
# - Stern et al. (2010), [arXiv:1503.01116](https://doi.org/10.48550/arXiv.1503.01116)
# - Moresco et al. (2012), [arXiv:1601.01701](https://doi.org/10.48550/arXiv.1601.01701)

# %%
#Load CC dataset and Build Full Covariance Matrix
filename = 'data/HzTable_MM_BC03.dat'
z, Hz, errHz = np.genfromtxt(filename, comments='#', usecols=(0,1,2), unpack=True, delimiter=',')
ref = np.genfromtxt(filename, comments='#', usecols=(3), unpack=True, dtype=str, delimiter=',')


filename = 'data/data_MM20.dat'
zmod, imf, slib, sps, spsooo = np.genfromtxt(filename, comments='#', usecols=(0,1,2,3,4), unpack=True)

cov_mat_diag = np.zeros((len(z), len(z)), dtype='float64')

for i in range(len(z)):
	cov_mat_diag[i,i] = errHz[i]**2

imf_intp = np.interp(z, zmod, imf)/100
slib_intp = np.interp(z, zmod, slib)/100
sps_intp = np.interp(z, zmod, sps)/100
spsooo_intp = np.interp(z, zmod, spsooo)/100

cov_mat_imf = np.zeros((len(z), len(z)), dtype='float64')
cov_mat_slib = np.zeros((len(z), len(z)), dtype='float64')
cov_mat_sps = np.zeros((len(z), len(z)), dtype='float64')
cov_mat_spsooo = np.zeros((len(z), len(z)), dtype='float64')

for i in range(len(z)):
	for j in range(len(z)):
		cov_mat_imf[i,j] = Hz[i] * imf_intp[i] * Hz[j] * imf_intp[j]
		cov_mat_slib[i,j] = Hz[i] * slib_intp[i] * Hz[j] * slib_intp[j]
		cov_mat_sps[i,j] = Hz[i] * sps_intp[i] * Hz[j] * sps_intp[j]
		cov_mat_spsooo[i,j] = Hz[i] * spsooo_intp[i] * Hz[j] * spsooo_intp[j]


cov_mat = cov_mat_spsooo+cov_mat_imf+cov_mat_diag
inv_cov_mat = inv(cov_mat)

cov_mat_cc = inv_cov_mat

# %% [markdown]
# # PantheonPlus Dataset (CosmoSIS Likelihood)
#
# **Source Link:** [Pantheon+ CosmoSIS Likelihood Script](https://github.com/PantheonPlusSH0ES/DataRelease/blob/main/Pantheon%2B_Data/5_COSMOLOGY/cosmosis_likelihoods/Pantheon%2B_only_cosmosis_likelihood.py)
# **Dataset Link:** [Pantheon+ Distances and Covariance](https://github.com/PantheonPlusSH0ES/DataRelease/tree/main/Pantheon%2B_Data/4_DISTANCES_AND_COVAR)
#
# ### Description
#
# This analysis utilizes the full **STAT+SYS** covariance matrix provided in the PantheonPlus data release to construct a supernova likelihood. The approach follows the CosmoSIS likelihood format and incorporates both statistical and systematic uncertainties in the SN Ia light curves.
#
# ### Citation Guidelines
#
# If you use this dataset or the associated likelihood script in your research, please cite the following key works:
#
# - **Pantheon+ Compilation and Analysis Methodology:**
#   - Brout et al. (2022), [arXiv:2112.03863](https://doi.org/10.48550/arXiv.2112.03863)
#   - Scolnic et al. (2022), [arXiv:2202.04077](https://doi.org/10.48550/arXiv.2202.04077)
#
# - **Covariance Matrix Construction:**
#   - Conley et al. (2011), [arXiv:1104.1443](https://doi.org/10.48550/arXiv.1104.1443)

# %%
#Load Pantheonplus dataset and Build the Covariance Matrix
values_filename = 'data/Pantheon+SH0ES.dat'
cov_filename = 'data/Pantheon+SH0ES_STAT+SYS.cov'

data = pd.read_csv(values_filename, sep=r'\s+')
origlen = len(data)
ww = (data['zHD'] > 0.01)  # Filter condition for zHD > 0.01
zcmb = data['zHD'][ww].values  # vpec corrected redshift (zCMB)
zhelio = data['zHEL'][ww].values  # Heliocentric redshift
mag = data['m_b_corr'][ww].values  # Corrected magnitudes
N = len(mag)

filename = cov_filename
#print("Loading covariance from {}".format(filename))
f = open(filename)
line = f.readline()
n = int(len(zcmb))
C = np.zeros((n,n))
ii = -1
jj = -1
mine = 999
maxe = -999
for i in range(origlen):
    jj = -1
    if ww[i]:
        ii += 1
    for j in range(origlen):
        if ww[j]:
            jj += 1
        val = float(f.readline())
        if ww[i]:
            if ww[j]:
                C[ii,jj] = val

f.close()
#print('Done')
cov = C
xdiag = 1/cov.diagonal()  # diagonal before marginalising constant
cov += 3**2
zmin = zcmb.min()
zmax = zcmb.max()
zmaxi = 1.1 ## we interpolate to 1.1 beyond that exact calc
#print("Pantheon SN: zmin=%f zmax=%f N=%i" % (zmin, zmax, N))
ninterp=150
zinter = np.linspace(1e-3, zmaxi, ninterp)
icov = la.inv(cov)

# %% [markdown]
# # DESI DR2 Dataset with Full Covariance
#
# **Source of Dataset:**
# [DESI BAO Data - GitHub (CobayaSampler)](https://github.com/CobayaSampler/bao_data)
#
# ### Description
#
# This analysis utilizes incorporates the **DESI Data Release 2 (DR2)** dataset, which includes baryon acoustic oscillation (BAO) measurements derived from over 14 million galaxies and quasars. The full covariance matrix is used in the likelihood analysis to properly account for measurement uncertainties and correlations between data points.
#
# The dataset is made publicly available and formatted for direct use in cosmological inference frameworks such as [Cobaya](https://cobaya.readthedocs.io/) and [CosmoMC](https://cosmologist.info/cosmomc/).
#
# ### Citation Guidelines
#
# If you use this dataset in your work, please cite the following:
#
# - **DESI Collaboration (2025)** : _DESI DR2 Results II: Measurements of Baryon Acoustic Oscillations and Cosmological Constraints_ [arXiv:2503.14738] : (https://doi.org/10.48550/arXiv.2503.14738)

# %%
#loading BAO dataset with Covarinace matrix
dirBD= "data/desi_gaussian_bao_ALL_GCcomb_mean.txt"
BaoData = np.genfromtxt(dirBD)
xarr = np.array(BaoData[:,0])
yarr = np.array(BaoData[:,1])

funarr = np.genfromtxt(dirBD,dtype='str')[:,2]
print(funarr)

def modelArr(name):
    mod = []

    for j in range(len(funarr)):
        if (funarr[j] == name):
             mod.append([xarr[j],yarr[j]])
    mod = np.array(mod)
    mod = mod[np.argsort(mod[:,0])]
    return mod

cov_bao = np.loadtxt("data/desi_gaussian_bao_ALL_GCcomb_cov.txt")
cov_bao_inv = np.linalg.inv(cov_bao)
# Out:
# ['DVrd' 'DMrd' 'DHrd' 'DMrd' 'DHrd' 'DMrd' 'DHrd' 'DMrd' 'DHrd' 'DMrd'
#  'DHrd' 'DHrd' 'DMrd']

# %% [markdown]
# 1. **Define the normalized Hubble function** $E(\theta, z)$:
#
# $$
# E(z) = \sqrt{\Omega_m (1 + z)^3 + (1 - \Omega_m)}
# $$
#
# 2. **The Hubble function** $H(\theta, z)$:
#
# $$
# H(z) = H_0 \times E(z)
# $$

# %%
#H functions
c = 299792.458

def E(theta,z):
    H0, Om, rd = theta
    OL = 1 - Om
    return np.sqrt(Om*(1+z)**3 + OL)

def H(theta,z):
    H0, Om, rd = theta
    arr = []
    for j in range(len(z)):
        arr.append(H0*E(theta,z[j]))
    arr = np.array(arr)
    return arr

H([67,0.32,147],[1,2,3])
# Out:
# array([120.6      , 204.5421228, 308.2      ])

# %% [markdown]
# 3. The comoving distance function $D_H(\theta, z)$:
#
# $$
# D_H(z) = \frac{c}{H(z)}
# $$
#
# 4. The comoving distance scaled by the sound horizon:
#
# $$
# \frac{D_H(z)}{r_d} = \frac{c}{H(z) \times r_d}
# $$

# %%
#DH functions
def DH(theta,z):
    H0, Om, rd = theta
    arr = []
    for j in range(len(z)):
        arr.append(c/(H0*E(theta,z[j])))
    arr = np.array(arr)
    return arr

def DHrd(theta,z):
    H0, Om, rd = theta
    arr = []

    for j in range(len(z)):
        arr.append(c/(H0*E(theta,z[j])*rd))
    arr = np.array(arr)
    return arr

DHrd([67,0.32,147],[1,2,3])
# Out:
# array([16.91048488,  9.97058429,  6.61714626])

# %% [markdown]
# The Sk function $S_k(\theta, x)$:
#
# $$
# S_k(x) =
# \begin{cases}
# \frac{\sin\left(\sqrt{-\Omega_k} \, x\right)}{\sqrt{-\Omega_k}} & \text{if } \Omega_k < -10^{-15} \\
# \frac{\sinh\left(\sqrt{\Omega_k} \, x\right)}{\sqrt{\Omega_k}} & \text{if } \Omega_k > 10^{-15} \\
# x & \text{if } \Omega_k = 0
# \end{cases}
# $$
#
# Where:
#
# * $\Omega_k$ is the curvature parameter (based on the `Ok` variable in your function).
# * $x$ is the input variable in the function.
#
# This function evaluates different cases based on the sign and magnitude of $\Omega_k$ (denoted as `Ok`), using either the sine or hyperbolic sine functions, or returning $x$ when $\Omega_k = 0$.

# %%
def Sk(theta,x):
    H0, Om, rd = theta
    Ok =0
    if Ok < -10**(-15):
        return np.sin(np.sqrt(-Ok)*x)/np.sqrt(-Ok)
    #if Ok == 0:
    #    return x
    elif Ok > 10**(-15):
        return np.sinh(np.sqrt(Ok)*x)/np.sqrt(Ok)
    else:
        return x

# %% [markdown]
# **Derivative of $\chi$ with respect to $z$** :
#
# $$
# \frac{d\chi}{dz} = \frac{1}{E(\theta, z)}
# $$
#
# **Integral of $\chi$** :
#
# $$
# \chi(z) = \int_0^z \frac{dz'}{E(\theta, z')}
# $$

# %%
# function that returns dDC/dz,df/dz
def dchidz(x,z, H0, Om, rd):
    return 1/E([H0, Om, rd],z)

def chiInt(theta,z):
    H0, Om, rd = theta
    z = np.hstack((np.array((0)), z))
    arr = odeint(dchidz,0,z,args=(H0, Om, rd,))
    return np.delete(arr ,0)

chiInt([67,0.32,147],[1,2,3])
# Out:
# array([0.7624812 , 1.18936468, 1.45585048])

# %% [markdown]
# 5. The comoving angular diameter distance is computed as: $D_M(\theta, z)$:
#
# $$
# D_M(z) = \frac{c}{H_0} \cdot S_k\left( \chi(z) \right)
# $$
#
# * $\chi(z) = \int_0^z \frac{c}{H(z')} \, dz'$ is the comoving radial distance
# * $S_k(\chi)$ accounts for spatial curvature:
#
# $$
# S_k(\chi) =
# \begin{cases}
# \frac{1}{\sqrt{\Omega_k}} \sinh\left(\sqrt{\Omega_k} \chi\right) & \text{if } \Omega_k > 0 \ (\text{open}) \\
# \chi & \text{if } \Omega_k = 0 \ (\text{flat}) \\
# \frac{1}{\sqrt{|\Omega_k|}} \sin\left(\sqrt{|\Omega_k|} \chi\right) & \text{if } \Omega_k < 0 \ (\text{closed})
# \end{cases}
# $$
#
# 6. The comoving angular diameter distance scaled by the sound horizon:
#
#
# $$
# \frac{D_M(z)}{r_d} = \frac{c}{H_0 \cdot r_d} \cdot S_k\left( \chi(z) \right)
# $$

# %%
#DM

def DM(theta,z):
    H0, Om, rd = theta
    chi = chiInt(theta,z)

    arr = []

    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/H0)
    arr = np.array(arr)
    arr.shape
    return arr

def DMrd(theta,z):
    H0, Om, rd = theta
    chi = chiInt(theta,z)

    arr = []

    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/(H0*rd))
    arr = np.array(arr)
    arr.shape
    return arr

DMrd([67,0.32,147],[1,2,3])
# Out:
# array([23.20906838, 36.20292027, 44.31444763])

# %% [markdown]
# 7. The volume-averaged distance combines radial and transverse distances and is defined as:
#
# $$
# D_V(z) = \left[ z \cdot D_H(z) \cdot D_M(z)^2 \right]^{1/3}
# $$
#
# * $D_H(z) = \dfrac{c}{H(z)}$: the comoving Hubble distance
# * $D_M(z)$: the comoving angular diameter distance
# * This is often used when the BAO measurement is spherically averaged.
#
# 8. The volume-averaged diameter distance scaled by the sound horizon:
#
# $$
# \frac{D_V(z)}{r_d} = \frac{ \left[ z \cdot D_H(z) \cdot D_M(z)^2 \right]^{1/3} }{r_d}
# $$

# %%
#DV

def DV(theta,z):
    H0, Om, rd = theta
    dh = DH(theta,z)
    dm = DM(theta,z)
    arr = []

    for i in range(len(z)):
        arr.append(np.cbrt(z[i]*dh[i]*dm[i]**2))
    arr = np.array(arr)
    arr.shape
    return arr

def DVrd(theta,z):

    H0, Om, rd = theta

    dh = DH(theta,z)
    dm = DM(theta,z)
    arr = []

    for i in range(len(z)):
        arr.append(np.cbrt(z[i]*dh[i]*dm[i]**2)/rd)
    arr = np.array(arr)
    arr.shape
    return arr

DVrd([67,0.32,147],[1,2,3])
# Out:
# array([20.88448766, 29.67649485, 33.90737919])

# %% [markdown]
# ### Luminosity Distance
#
# $$
# D_L(z) = (1 + z) \cdot \frac{c \cdot \chi(z)}{H_0}
# $$
#
# ### Distance Modulus
#
# $$
# \mu(z) = 5 \log_{10} \left( D_L(z) \right) + 25
# $$

# %%
def DL(theta,z):
    H0, Om, rd = theta
    chi = chiInt(theta,z)
    return c*chi/H0

def mu(theta,z):
    H0, Om, rd = theta
    dL = DL(theta,z)
    mu = []

    for i in range(len(z)):
        mu.append(5*np.log10(dL[i]*(1+z[i])) + 25)
    mu = np.array(mu)
    mu.shape
    return mu

# %%
def Omega_Lambda(theta):
    H0, Om, rd = theta
    OL = 1 - Om
    return OL

# %% [markdown]
# ### Log Likelihood Function for Cosmic Chronometer Measurements
#
# Given a model prediction $H(z; \theta)$, observed data $H_z$, and the inverse covariance matrix $\mathbf{C}^{-1}$, the chi-squared statistic is computed as:
#
# $$
# \chi^2 = \left( H(z; \theta) - H_z \right)^T \cdot \mathbf{C}^{-1} \cdot \left( H(z; \theta) - H_z \right)
# $$
#
# The corresponding log-likelihood is:
#
# $$
# \ln \mathcal{L}(\theta) = -\frac{1}{2} \chi^2
# $$
#
#
# ### Output Statistics
#
# The function also returns:
#
# * Minimum chi-squared: $\chi^2_{\text{min}}$
# * Total number of data points: $N$
# * Reduced chi-squared:
#
# $$
# \chi^2_{\text{red}} = \frac{\chi^2}{N - k}
# $$
#
# * $p$-value:
#
# $$
# p = 1 - F_{\chi^2}(\chi^2; \, \text{dof} = N - k)
# $$
#
# * Derived Cosmological Parameters:
#
# $$
# \Omega_\Lambda = 1 - \Omega_m \quad (\text{In the case Dark Energy Density })
# $$

# %%
def lnlike(theta,model,z,Hz,cov_mat_cc):
    prediction = model(theta,z)
    residualcc = prediction - Hz
    chi2 = residualcc.T @ cov_mat_cc @ residualcc
    return chi2

def lnlikeCC(theta):
    chi = 0; i = 0
    chi += lnlike(theta, H, z, Hz, cov_mat_cc)
    i += len(z)
    OL = Omega_Lambda(theta)
    return -chi, [i, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeCC([67,0.32,147]))
# Out:
# (np.float64(-6.183367402883179), [15, np.float64(0.5152806169069316), np.float64(0.906557694340706), 0.6799999999999999])

# %% [markdown]
# ### Log Likelihood Function for BAO Dataset with Full Covariance
#
# Given model predictions $\hat{y}_i = f_i(z_i; \theta)$ (e.g., BAO observables like $D_H$, $D_V$, and $D_A$, etc.), observed data $y_i$, and the inverse covariance matrix $\mathbf{C}^{-1}$, the chi-squared statistic is computed as:
#
# $$
# \chi^2(\theta) = \left( \hat{y}(\theta) - y \right)^T \cdot \mathbf{C}^{-1} \cdot \left( \hat{y}(\theta) - y \right)
# $$
#
# The corresponding log-likelihood is:
#
# $$
# \ln \mathcal{L}(\theta) = -\frac{1}{2} \chi^2(\theta)
# $$

# %%
# likelihood with covariance matrix
def lnlikecov(theta, model, x, y, cov):
    prediction = []

    for i in range(len(model)):
        fun = model[i]
        prediction.append(eval(fun)(theta, [x[i]]))
    prediction = np.array(prediction)[:, 0]
    vec = (prediction - y)
    result = np.dot(np.dot(vec, cov), vec.T)
    return result

print(lnlikecov([67, 0.32, 147], funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv))
# Out:
# 40.55527665589692

# %% [markdown]
# This function computes the log-likelihood of BAO data given cosmological parameters $\theta$. It calculates the chi-squared statistic comparing model predictions to observations using the inverse covariance matrix, then returns the negative chi-squared (log-likelihood), reduced chi-squared, p-value, and the derived parameter $\Omega_\Lambda$, providing a measure of fit quality and model consistency with the data.

# %%
def lnlikeBAO(theta):
    x = np.array(BaoData[:, 0])
    y = np.array(BaoData[:, 1])

    # Use your manually loaded inverse covariance matrix
    chi = lnlikecov(theta, funarr, x, y, cov_bao_inv)
    i = len(x)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi / (i - len(theta)), 1 - stats.chi2.cdf(x=chi, df=(i - len(theta))), OL]

lnlikeBAO([67,0.32,147])
# Out:
# (np.float64(-40.55527665589692),
#  [np.float64(40.55527665589692),
#   np.float64(4.0555276655896915),
#   np.float64(1.3524100608619527e-05),
#   0.6799999999999999])

# %% [markdown]
# ### Log Likelihood Function for PantheonPlus Dataset with Full Covariance
#
# In this analysis, I marginalize over the nuisance parameter $\mathcal{M}$ (the absolute magnitude offset) using the analytic approach described in Astier et al. (2001) [arXiv:astro-ph/0104009](https://arxiv.org/abs/astro-ph/0104009v1). The method uses the difference
#
# $$
# \Delta = 5 \log_{10} \left[d'_L(\theta, z_i)\right] - 5 \log_{10} \left[d'_L(\theta_{\text{true}}, z_i)\right]
# \quad \text{(Equation A.8)}
# $$
#
# where $d'_L$ is the luminosity distance.
#
# By construction, the minimized chi-squared at the true parameters satisfies
#
# $$
# \hat{\chi}^2_{\min} = \hat{\chi}^2(\theta_{\text{true}}) = 0.
# $$
#
# Assuming no prior knowledge of $M$, the likelihood is marginalized by integrating the general $\chi^2$ function over $M \in (-\infty, \infty)$:
#
# $$
# \tilde{\chi}^2 \equiv \chi^2_{M\text{-int}} = -2 \ln \left[\int_{-\infty}^{\infty} dM \exp\left(-\frac{1}{2} \chi^2 \right)\right]
# \quad \text{(Equation A.9)}
# $$
#
# This integral can be evaluated analytically to give:
#
# $$
# \tilde{\chi}^2 = \hat{\chi}^2 - \frac{B^2}{C} + \ln \left(\frac{C}{2 \pi}\right)
# \quad \text{(Equation A.10)}
# $$
#
# where
#
# $$
# B = \sum_{i=1}^n \frac{\Delta_i}{\sigma_i^2}
# \quad \text{(Equation A.11)}
# $$
#
# and
#
# $$
# C = \sum_{i=1}^n \frac{1}{\sigma_i^2}
# \quad \text{(Equation A.12)}
# $$
#
# Here, $\sigma_i^2$ are the variances from the covariance matrix.
#
# ### Reference
#
# ### Citation Guidelines
#
# If you use this liklihood in your work, please cite the following:
#
# - **Astier et al. (2001)** : _Supernovae and the Nature of the Dark Energy_ : [arXiv:astro-ph/0104009](https://arxiv.org/abs/astro-ph/0104009v1)

# %%
def A(theta, x, y, icov):
    Mu = mu(theta, x)
    residual = y - Mu
    chit2 = residual.T @ icov @ residual
    B = np.sum(residual @ icov)
    C = np.sum(icov)
    chi2 = chit2 - (B**2 / C) + np.log(C / (2 * np.pi))
    return chi2

def lnlikeSNIa(theta):
    chi = A(theta, zcmb, mag, icov)
    i = len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeSNIa([67,0.32,147]))
# Out:
# (np.float64(-1400.0153971457628), [np.float64(1400.0153971457628), np.float64(0.8821773138914699), np.float64(0.9997167053005009), 0.6799999999999999])

# %% [markdown]
# $\mathcal{L}_{\text{CC + DESI DR2 + PP}} = \mathcal{L}_{\text{CC}} \times \mathcal{L}_{\text{DESI DR2}},$

# %%
def lnlikeCCBAO(theta):

    chi = lnlikecov(theta, funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv)
    i = len(BaoData[:, 0])
    chi += lnlike(theta, H, z, Hz, cov_mat_cc); i += len(z)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1 - stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeCCBAO([67,0.32,147]))
# Out:
# (np.float64(-46.738644058780096), [np.float64(46.738644058780096), np.float64(1.869545762351204), np.float64(0.0052628017837303975), 0.6799999999999999])

# %% [markdown]
# $\mathcal{L}_{\text{CC + DESI DR2 + PP}} = \mathcal{L}_{\text{CC}} \times \mathcal{L}_{\text{PP}} \times \mathcal{L}_{\text{DESI DR2}},$

# %%
def lnlikeCCBAOPP(theta):

    chi = lnlikecov(theta, funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv)
    i = len(BaoData[:, 0])
    chi += lnlike(theta, H, z, Hz, cov_mat_cc); i += len(z)
    chi += A(theta, zcmb, mag, icov);i += len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1 - stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeCCBAOPP([67,0.32,147]))
# Out:
# (np.float64(-1446.7540412045428), [np.float64(1446.7540412045428), np.float64(0.8958229357303671), np.float64(0.9988861076147266), 0.6799999999999999])

# %%
runs = 100

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
def uniprior(hypercube):
    prior = []
    prior.append(UniformPrior(50.,100.)(hypercube[0]))
    prior.append(UniformPrior(0.,1.)(hypercube[1]))
    prior.append(UniformPrior(100.,200.)(hypercube[2]))
    return prior

# %%
settingsCCBAO = PolyChordSettings(3,4)
settingsCCBAO.file_root = 'CC + DESI DR2'
settingsCCBAO.nlive = runs
settingsCCBAO.do_clustering = True
settingsCCBAO.read_resume = False

settingsCCBAOPP = PolyChordSettings(3,4)
settingsCCBAOPP.file_root = 'CC + DESI DR2 + PP'
settingsCCBAOPP.nlive = runs
settingsCCBAOPP.do_clustering = True
settingsCCBAOPP.read_resume = False

# %%
outputCCBAO = pypolychord.run_polychord(lnlikeCCBAO, 3,4, settingsCCBAO, uniprior, dumper)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     100
# nDims    :       3
# nDerived :       4
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/CC + BAO.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.913E-03 seconds
# number of repeats:           15
# started sampling
#
# Last dead point: [ 6.59818853e+01  6.37504357e-01  1.50803088e+02  3.86340143e+03
#   1.54536057e+02  0.00000000e+00  3.62495643e-01 -5.74235458e+03
#  -3.86340143e+03]
# ________________
# lives      |100 |
# phantoms   |866 |
# posteriors |101 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 101
# nposterior =                 101
# nequals    =                   1
# nlike      =                2697
# <nlike>    =          25.97   (           1.73 per slice )
# log(Z)     =        -3869.36 +/-  0.83
# log(Z_1)   =        -3869.36 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 8.80781265e+01  2.64991231e-01  1.08186264e+02  1.20644332e+03
#   4.82577329e+01  0.00000000e+00  7.35008769e-01 -1.43150693e+03
#  -1.20644332e+03]
# _________________
# lives      | 100 |
# phantoms   |1315 |
# posteriors | 202 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 202
# nposterior =                 202
# nequals    =                   1
# nlike      =                7323
# <nlike>    =          46.26   (           3.08 per slice )
# log(Z)     =        -1213.41 +/-  0.84
# log(Z_1)   =        -1213.41 +/-  0.84 (still evaluating)
#
#
#
# Last dead point: [ 7.76652856e+01  2.64343372e-01  1.42391135e+02  4.57307490e+02
#   1.82922996e+01  0.00000000e+00  7.35656628e-01 -1.00842771e+03
#  -4.57307490e+02]
# _________________
# lives      | 100 |
# phantoms   |1477 |
# posteriors | 303 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 303
# nposterior =                 303
# nequals    =                   1
# nlike      =               12383
# <nlike>    =          50.60   (           3.37 per slice )
# log(Z)     =         -465.28 +/-  0.84
# log(Z_1)   =         -465.28 +/-  0.84 (still evaluating)
#
#
#
# Last dead point: [ 7.87586653e+01  2.76857171e-01  1.26567898e+02  1.92783229e+02
#   7.71132915e+00  0.00000000e+00  7.23142829e-01 -6.88587779e+02
#  -1.92783229e+02]
# _________________
# lives      | 100 |
# phantoms   |1502 |
# posteriors | 404 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 404
# nposterior =                 404
# nequals    =                   2
# nlike      =               17953
# <nlike>    =          55.70   (           3.71 per slice )
# log(Z)     =         -200.77 +/-  0.58
# log(Z_1)   =         -200.77 +/-  0.58 (still evaluating)
#
#
#
# Last dead point: [ 7.42550123e+01  2.90180959e-01  1.34238399e+02  9.73990602e+01
#   3.89596241e+00  1.71392789e-10  7.09819041e-01 -1.75766986e+02
#  -9.73990602e+01]
# _________________
# lives      | 100 |
# phantoms   |1580 |
# posteriors | 505 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 505
# nposterior =                 505
# nequals    =                   2
# nlike      =               23877
# <nlike>    =          59.24   (           3.95 per slice )
# log(Z)     =         -106.64 +/-  0.61
# log(Z_1)   =         -106.64 +/-  0.61 (still evaluating)
#
#
#
# Last dead point: [ 8.54010346e+01  2.95141851e-01  1.17918530e+02  4.75929243e+01
#   1.90371697e+00  4.17113297e-03  7.04858149e-01 -8.69479896e+01
#  -4.75929243e+01]
# __________________________
# lives      | 41 | 41 | 18 |
# phantoms   |620 |577 |355 |
# posteriors |536 |568 |512 |
# equals     |  4 |  2 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       4
# ndead      =                 615
# nposterior =                 615
# nequals    =                   7
# nlike      =               36682
# <nlike>    =         128.05   (           8.54 per slice )
# log(Z)     =          -56.75 +/-  0.39
# log(Z_1)   =          -57.36 +/-  0.49 (still evaluating)
# log(Z_2)   =          -57.65 +/-  0.50 (still evaluating)
# log(Z_3)   =          -63.46 +/-  0.79
# log(Z_4)   =          -69.05 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 82.0561577    0.29083314 124.18658021  28.41770483   1.13670819
#    0.28898596   0.70916686 -28.99730707 -28.41770483]
# _______________________________
# lives      | 23 | 35 | 32 | 10 |
# phantoms   |379 |687 |407 |177 |
# posteriors |595 |526 |610 |574 |
# equals     |  5 |  4 |  6 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       4 /       5
# ndead      =                 736
# nposterior =                 736
# nequals    =                  12
# nlike      =               57449
# <nlike>    =         207.67   (          13.84 per slice )
# log(Z)     =          -38.14 +/-  0.36
# log(Z_1)   =          -39.12 +/-  0.49 (still evaluating)
# log(Z_2)   =          -39.76 +/-  0.67 (still evaluating)
# log(Z_3)   =          -39.73 +/-  0.52 (still evaluating)
# log(Z_4)   =          -40.06 +/-  0.49 (still evaluating)
# log(Z_5)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 77.44510238   0.30230933 130.53974982  22.0488181    0.88195272
#    0.63292343   0.69769067 -25.19493353 -22.0488181 ]
# _________________________________________
# lives      |  70 |  12 |   5 |   7 |   6 |
# phantoms   |1166 | 289 |  88 | 101 | 157 |
# posteriors | 570 | 582 | 598 | 617 | 623 |
# equals     |  17 |   4 |   1 |   7 |   4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       5 /       7
# ndead      =                 848
# nposterior =                 848
# nequals    =                  18
# nlike      =               78206
# <nlike>    =         207.57   (          13.84 per slice )
# log(Z)     =          -31.39 +/-  0.29
# log(Z_1)   =          -32.17 +/-  0.37 (still evaluating)
# log(Z_2)   =          -33.15 +/-  0.45 (still evaluating)
# log(Z_3)   =          -33.63 +/-  0.53 (still evaluating)
# log(Z_4)   =          -33.63 +/-  0.50
# log(Z_5)   =          -33.77 +/-  0.51 (still evaluating)
# log(Z_6)   =          -36.49 +/-  0.72 (still evaluating)
# log(Z_7)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 70.32658693   0.3100262  143.30032623  19.36959416   0.77478377
#    0.77906312   0.6899738  -21.83036435 -19.36959416]
# _____________________________
# lives      |  84 |  15 |   1 |
# phantoms   |1368 | 317 |  46 |
# posteriors | 636 | 593 | 631 |
# equals     |  41 |   8 |   6 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       7
# ndead      =                 946
# nposterior =                 946
# nequals    =                  39
# nlike      =               91036
# <nlike>    =         128.30   (           8.55 per slice )
# log(Z)     =          -29.01 +/-  0.30
# log(Z_1)   =          -29.55 +/-  0.35 (still evaluating)
# log(Z_2)   =          -30.77 +/-  0.47 (still evaluating)
# log(Z_3)   =          -31.67 +/-  0.47
# log(Z_4)   =          -31.76 +/-  0.49 (still evaluating)
# log(Z_5)   =          -31.86 +/-  0.56
# log(Z_6)   =          -33.63 +/-  0.50
# log(Z_7)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 66.82265711   0.30516149 151.31170231  17.80951507   0.7123806
#    0.85036919   0.69483851 -17.98354693 -17.80951507]
# _______________________
# lives      |  87 |  13 |
# phantoms   |1203 | 210 |
# posteriors | 715 | 612 |
# equals     |  84 |  18 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       7
# ndead      =                1045
# nposterior =                1045
# nequals    =                  63
# nlike      =              102327
# <nlike>    =         112.91   (           7.53 per slice )
# log(Z)     =          -27.79 +/-  0.31
# log(Z_1)   =          -28.20 +/-  0.35 (still evaluating)
# log(Z_2)   =          -29.24 +/-  0.45 (still evaluating)
# log(Z_3)   =          -31.36 +/-  0.57
# log(Z_4)   =          -31.67 +/-  0.47
# log(Z_5)   =          -31.86 +/-  0.56
# log(Z_6)   =          -33.63 +/-  0.50
# log(Z_7)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 66.24622832   0.30041106 153.12353772  17.22902809   0.68916112
#    0.87331945   0.69958894 -17.80385896 -17.22902809]
# _____________________________
# lives      |  93 |   2 |   5 |
# phantoms   |1308 |  51 | 118 |
# posteriors | 796 | 616 | 619 |
# equals     | 151 |  21 |  23 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       9
# ndead      =                1140
# nposterior =                1140
# nequals    =                  66
# nlike      =              113270
# <nlike>    =         109.43   (           7.30 per slice )
# log(Z)     =          -27.25 +/-  0.31
# log(Z_1)   =          -27.61 +/-  0.35 (still evaluating)
# log(Z_2)   =          -29.45 +/-  0.47 (still evaluating)
# log(Z_3)   =          -29.85 +/-  0.49
# log(Z_4)   =          -30.25 +/-  0.51 (still evaluating)
# log(Z_5)   =          -31.36 +/-  0.57
# log(Z_6)   =          -31.67 +/-  0.47
# log(Z_7)   =          -31.86 +/-  0.56
# log(Z_8)   =          -33.63 +/-  0.50
# log(Z_9)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 66.96976777   0.30083229 151.1449092   16.89592228   0.67583689
#    0.88553404   0.69916771 -17.09727891 -16.89592228]
# _________________
# lives      | 100 |
# phantoms   |1283 |
# posteriors | 879 |
# equals     | 188 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       9
# ndead      =                1231
# nposterior =                1231
# nequals    =                  85
# nlike      =              120348
# <nlike>    =          70.78   (           4.72 per slice )
# log(Z)     =          -27.03 +/-  0.32
# log(Z_1)   =          -27.37 +/-  0.35 (still evaluating)
# log(Z_2)   =          -29.18 +/-  0.48
# log(Z_3)   =          -29.85 +/-  0.49
# log(Z_4)   =          -30.08 +/-  0.50
# log(Z_5)   =          -31.36 +/-  0.57
# log(Z_6)   =          -31.67 +/-  0.47
# log(Z_7)   =          -31.86 +/-  0.56
# log(Z_8)   =          -33.63 +/-  0.50
# log(Z_9)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 68.38877985   0.29783758 148.58235094  16.71800499   0.6687202
#    0.89176646   0.70216242 -16.7476444  -16.71800499]
# _________________
# lives      | 100 |
# phantoms   |1303 |
# posteriors | 980 |
# equals     | 219 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       9
# ndead      =                1332
# nposterior =                1332
# nequals    =                  94
# nlike      =              127602
# <nlike>    =          72.54   (           4.84 per slice )
# log(Z)     =          -26.94 +/-  0.32
# log(Z_1)   =          -27.24 +/-  0.36 (still evaluating)
# log(Z_2)   =          -29.18 +/-  0.48
# log(Z_3)   =          -29.85 +/-  0.49
# log(Z_4)   =          -30.08 +/-  0.50
# log(Z_5)   =          -31.36 +/-  0.57
# log(Z_6)   =          -31.67 +/-  0.47
# log(Z_7)   =          -31.86 +/-  0.56
# log(Z_8)   =          -33.63 +/-  0.50
# log(Z_9)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 67.81114502   0.29691215 149.81587484  16.64328104   0.66573124
#    0.89432299   0.70308785 -16.71112901 -16.64328104]
# _________________
# lives      | 100 |
# phantoms   |1294 |
# posteriors |1081 |
# equals     | 229 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       9
# ndead      =                1433
# nposterior =                1433
# nequals    =                  97
# nlike      =              134791
# <nlike>    =          71.89   (           4.79 per slice )
# log(Z)     =          -26.91 +/-  0.32
# log(Z_1)   =          -27.19 +/-  0.36 (still evaluating)
# log(Z_2)   =          -29.18 +/-  0.48
# log(Z_3)   =          -29.85 +/-  0.49
# log(Z_4)   =          -30.08 +/-  0.50
# log(Z_5)   =          -31.36 +/-  0.57
# log(Z_6)   =          -31.67 +/-  0.47
# log(Z_7)   =          -31.86 +/-  0.56
# log(Z_8)   =          -33.63 +/-  0.50
# log(Z_9)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 69.02712031   0.29921015 146.87256521  16.61794201   0.66471768
#    0.8951817    0.70078985 -16.65111418 -16.61794201]
# _________________
# lives      | 100 |
# phantoms   |1551 |
# posteriors |1182 |
# equals     | 229 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       9
# ndead      =                1534
# nposterior =                1534
# nequals    =                  98
# nlike      =              142102
# <nlike>    =          73.11   (           4.87 per slice )
# log(Z)     =          -26.89 +/-  0.32
# log(Z_1)   =          -27.18 +/-  0.36 (still evaluating)
# log(Z_2)   =          -29.18 +/-  0.48
# log(Z_3)   =          -29.85 +/-  0.49
# log(Z_4)   =          -30.08 +/-  0.50
# log(Z_5)   =          -31.36 +/-  0.57
# log(Z_6)   =          -31.67 +/-  0.47
# log(Z_7)   =          -31.86 +/-  0.56
# log(Z_8)   =          -33.63 +/-  0.50
# log(Z_9)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 68.19694173   0.29727262 148.89082288  16.60146528   0.66405861
#    0.89573784   0.70272738 -16.61875205 -16.60146528]
# _________________
# lives      | 100 |
# phantoms   |1651 |
# posteriors |1283 |
# equals     | 231 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       9
# ndead      =                1635
# nposterior =                1635
# nequals    =                  98
# nlike      =              149368
# <nlike>    =          72.66   (           4.84 per slice )
# log(Z)     =          -26.89 +/-  0.32
# log(Z_1)   =          -27.17 +/-  0.36 (still evaluating)
# log(Z_2)   =          -29.18 +/-  0.48
# log(Z_3)   =          -29.85 +/-  0.49
# log(Z_4)   =          -30.08 +/-  0.50
# log(Z_5)   =          -31.36 +/-  0.57
# log(Z_6)   =          -31.67 +/-  0.47
# log(Z_7)   =          -31.86 +/-  0.56
# log(Z_8)   =          -33.63 +/-  0.50
# log(Z_9)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 68.96007459   0.29758395 147.1979485   16.58865437   0.66354617
#    0.89616903   0.70241605 -16.65403883 -16.58865437]
# _________________
# lives      | 100 |
# phantoms   |1422 |
# posteriors |1384 |
# equals     | 233 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       9
# ndead      =                1736
# nposterior =                1736
# nequals    =                  98
# nlike      =              156546
# <nlike>    =          71.78   (           4.79 per slice )
# log(Z)     =          -26.89 +/-  0.32
# log(Z_1)   =          -27.17 +/-  0.36 (still evaluating)
# log(Z_2)   =          -29.18 +/-  0.48
# log(Z_3)   =          -29.85 +/-  0.49
# log(Z_4)   =          -30.08 +/-  0.50
# log(Z_5)   =          -31.36 +/-  0.57
# log(Z_6)   =          -31.67 +/-  0.47
# log(Z_7)   =          -31.86 +/-  0.56
# log(Z_8)   =          -33.63 +/-  0.50
# log(Z_9)   =          -63.46 +/-  0.79
#
#
#
# Last dead point: [ 68.71017638   0.29774472 147.74846203  16.57722786   0.66308911
#    0.89655272   0.70225528 -16.58951483 -16.57722786]
#  ____________________________________________________
# |                                                    |
# | ndead  =         1844                              |
# | log(Z) =          -26.88410 +/-            0.32115 |
# |____________________________________________________|

# %%
outputCCBAOPP = pypolychord.run_polychord(lnlikeCCBAOPP, 3,4, settingsCCBAOPP, uniprior, dumper)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     100
# nDims    :       3
# nDerived :       4
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/CC + BAO + PP.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.363E-02 seconds
# number of repeats:           15
# started sampling
#
# Last dead point: [ 9.14199933e+01  7.47366705e-01  1.09257867e+02  7.79603305e+03
#   4.82726505e+00  0.00000000e+00  2.52633295e-01 -9.67813675e+03
#  -7.79603305e+03]
# ________________
# lives      |100 |
# phantoms   |948 |
# posteriors |101 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 101
# nposterior =                 101
# nequals    =                   1
# nlike      =                2508
# <nlike>    =          24.08   (           1.61 per slice )
# log(Z)     =        -7801.99 +/-  0.83
# log(Z_1)   =        -7801.99 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 8.68297060e+01  6.40924051e-01  1.04881160e+02  3.18342237e+03
#   1.97115936e+00  0.00000000e+00  3.59075949e-01 -3.38278477e+03
#  -3.18342237e+03]
# _________________
# lives      | 100 |
# phantoms   |1227 |
# posteriors | 202 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 202
# nposterior =                 202
# nequals    =                   1
# nlike      =                6980
# <nlike>    =          44.72   (           2.98 per slice )
# log(Z)     =        -3190.27 +/-  0.79
# log(Z_1)   =        -3190.27 +/-  0.79 (still evaluating)
#
#
#
# Last dead point: [ 5.35714225e+01  4.88514448e-01  1.59656978e+02  2.10458439e+03
#   1.30314823e+00  1.55431223e-15  5.11485552e-01 -2.34089104e+03
#  -2.10458439e+03]
# _________________
# lives      | 100 |
# phantoms   |1370 |
# posteriors | 303 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 303
# nposterior =                 303
# nequals    =                   3
# nlike      =               11865
# <nlike>    =          48.85   (           3.26 per slice )
# log(Z)     =        -2112.10 +/-  0.69
# log(Z_1)   =        -2112.10 +/-  0.69 (still evaluating)
#
#
#
# Last dead point: [ 7.42224042e+01  2.76369407e-01  1.33243492e+02  1.68843642e+03
#   1.04547147e+00  9.94403103e-02  7.23630593e-01 -1.69349680e+03
#  -1.68843642e+03]
# _________________
# lives      | 100 |
# phantoms   |1449 |
# posteriors | 404 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 404
# nposterior =                 404
# nequals    =                   1
# nlike      =               17214
# <nlike>    =          53.49   (           3.57 per slice )
# log(Z)     =        -1696.80 +/-  0.67
# log(Z_1)   =        -1696.80 +/-  0.67 (still evaluating)
#
#
#
# Last dead point: [ 5.71609135e+01  3.89939665e-01  1.65031029e+02  1.52549777e+03
#   9.44580665e-01  9.44432299e-01  6.10060335e-01 -1.67482433e+03
#  -1.52549777e+03]
# _________________
# lives      | 100 |
# phantoms   |1443 |
# posteriors | 505 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 505
# nposterior =                 505
# nequals    =                   2
# nlike      =               22975
# <nlike>    =          57.61   (           3.84 per slice )
# log(Z)     =        -1535.24 +/-  0.76
# log(Z_1)   =        -1535.24 +/-  0.76 (still evaluating)
#
#
#
# Last dead point: [ 9.36001784e+01  3.00808963e-01  1.07398224e+02  1.46671588e+03
#   9.08183209e-01  9.96337730e-01  6.99191037e-01 -1.50150922e+03
#  -1.46671588e+03]
# _________________
# lives      | 100 |
# phantoms   |1549 |
# posteriors | 606 |
# equals     |   6 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 606
# nposterior =                 606
# nequals    =                   8
# nlike      =               29281
# <nlike>    =          63.06   (           4.20 per slice )
# log(Z)     =        -1475.65 +/-  0.38
# log(Z_1)   =        -1475.65 +/-  0.38 (still evaluating)
#
#
#
# Last dead point: [ 6.13080368e+01  2.98731856e-01  1.67334260e+02  1.43929242e+03
#   8.91202734e-01  9.99311968e-01  7.01268144e-01 -1.47677968e+03
#  -1.43929242e+03]
# _________________
# lives      | 100 |
# phantoms   |1303 |
# posteriors | 707 |
# equals     |  10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 707
# nposterior =                 707
# nequals    =                  10
# nlike      =               36165
# <nlike>    =          68.84   (           4.59 per slice )
# log(Z)     =        -1448.64 +/-  0.35
# log(Z_1)   =        -1448.64 +/-  0.35 (still evaluating)
#
#
#
# Last dead point: [ 7.65143938e+01  2.98953282e-01  1.33507387e+02  1.43006625e+03
#   8.85489941e-01  9.99631402e-01  7.01046718e-01 -1.43946127e+03
#  -1.43006625e+03]
# _________________
# lives      | 100 |
# phantoms   |1422 |
# posteriors | 808 |
# equals     |  16 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 808
# nposterior =                 808
# nequals    =                  19
# nlike      =               43532
# <nlike>    =          73.67   (           4.91 per slice )
# log(Z)     =        -1439.82 +/-  0.32
# log(Z_1)   =        -1439.82 +/-  0.32 (still evaluating)
#
#
#
# Last dead point: [ 6.51191829e+01  3.22133467e-01  1.52916497e+02  1.42432201e+03
#   8.81933133e-01  9.99754075e-01  6.77866533e-01 -1.42999705e+03
#  -1.42432201e+03]
# _________________
# lives      | 100 |
# phantoms   |1248 |
# posteriors | 909 |
# equals     |  28 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 909
# nposterior =                 909
# nequals    =                  26
# nlike      =               50877
# <nlike>    =          73.45   (           4.90 per slice )
# log(Z)     =        -1434.74 +/-  0.31
# log(Z_1)   =        -1434.74 +/-  0.31 (still evaluating)
#
#
#
# Last dead point: [ 7.08133433e+01  2.92970814e-01  1.43602052e+02  1.42187845e+03
#   8.80420094e-01  9.99793750e-01  7.07029186e-01 -1.42369476e+03
#  -1.42187845e+03]
# _________________
# lives      | 100 |
# phantoms   |1386 |
# posteriors |1010 |
# equals     |  81 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1010
# nposterior =                1010
# nequals    =                  71
# nlike      =               58292
# <nlike>    =          74.15   (           4.94 per slice )
# log(Z)     =        -1432.30 +/-  0.30
# log(Z_1)   =        -1432.30 +/-  0.30 (still evaluating)
#
#
#
# Last dead point: [ 6.88979349e+01  2.97222069e-01  1.47763245e+02  1.42056382e+03
#   8.79606077e-01  9.99812553e-01  7.02777931e-01 -1.42396500e+03
#  -1.42056382e+03]
# _________________
# lives      | 100 |
# phantoms   |1466 |
# posteriors |1091 |
# equals     | 133 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                1105
# nposterior =                1105
# nequals    =                  82
# nlike      =               66925
# <nlike>    =          86.33   (           5.76 per slice )
# log(Z)     =        -1431.31 +/-  0.30
# log(Z_1)   =        -1431.51 +/-  0.31 (still evaluating)
# log(Z_2)   =        -1433.01 +/-  0.32
#
#
#
# Last dead point: [ 6.70509111e+01  3.01060870e-01  1.51283262e+02  1.41969537e+03
#   8.79068339e-01  9.99824087e-01  6.98939130e-01 -1.41987474e+03
#  -1.41969537e+03]
# _________________
# lives      | 100 |
# phantoms   |1326 |
# posteriors |1192 |
# equals     | 219 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                1206
# nposterior =                1206
# nequals    =                 138
# nlike      =               74192
# <nlike>    =          72.67   (           4.84 per slice )
# log(Z)     =        -1430.77 +/-  0.31
# log(Z_1)   =        -1430.88 +/-  0.31 (still evaluating)
# log(Z_2)   =        -1433.01 +/-  0.32
#
#
#
# Last dead point: [ 6.75355646e+01  3.03910773e-01  1.49833907e+02  1.41933408e+03
#   8.78844629e-01  9.99828689e-01  6.96089227e-01 -1.41936809e+03
#  -1.41933408e+03]
# _________________
# lives      | 100 |
# phantoms   |1373 |
# posteriors |1293 |
# equals     | 283 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                1307
# nposterior =                1307
# nequals    =                 174
# nlike      =               81437
# <nlike>    =          72.45   (           4.83 per slice )
# log(Z)     =        -1430.53 +/-  0.31
# log(Z_1)   =        -1430.62 +/-  0.31 (still evaluating)
# log(Z_2)   =        -1433.01 +/-  0.32
#
#
#
# Last dead point: [ 6.85796508e+01  3.04754655e-01  1.47401416e+02  1.41915375e+03
#   8.78732972e-01  9.99830944e-01  6.95245345e-01 -1.41942322e+03
#  -1.41915375e+03]
# _________________
# lives      | 100 |
# phantoms   |1420 |
# posteriors |1394 |
# equals     | 315 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                1408
# nposterior =                1408
# nequals    =                 191
# nlike      =               88633
# <nlike>    =          71.96   (           4.80 per slice )
# log(Z)     =        -1430.44 +/-  0.31
# log(Z_1)   =        -1430.52 +/-  0.31 (still evaluating)
# log(Z_2)   =        -1433.01 +/-  0.32
#
#
#
# Last dead point: [ 6.76529363e+01  3.04045460e-01  1.49242823e+02  1.41905906e+03
#   8.78674339e-01  9.99832117e-01  6.95954540e-01 -1.41950590e+03
#  -1.41905906e+03]
# _________________
# lives      | 100 |
# phantoms   |1345 |
# posteriors |1495 |
# equals     | 330 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                1509
# nposterior =                1509
# nequals    =                 198
# nlike      =               95869
# <nlike>    =          72.36   (           4.82 per slice )
# log(Z)     =        -1430.40 +/-  0.31
# log(Z_1)   =        -1430.48 +/-  0.31 (still evaluating)
# log(Z_2)   =        -1433.01 +/-  0.32
#
#
#
# Last dead point: [ 6.81468755e+01  3.05049306e-01  1.48199182e+02  1.41901397e+03
#   8.78646423e-01  9.99832672e-01  6.94950694e-01 -1.41903054e+03
#  -1.41901397e+03]
# _____________________________
# lives      |  64 |   8 |  28 |
# phantoms   | 955 | 109 | 389 |
# posteriors |1539 |1522 |1527 |
# equals     | 331 | 332 | 331 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       4
# ndead      =                1612
# nposterior =                1612
# nequals    =                 201
# nlike      =              113129
# <nlike>    =         172.60   (          11.51 per slice )
# log(Z)     =        -1430.38 +/-  0.31
# log(Z_1)   =        -1431.27 +/-  0.32 (still evaluating)
# log(Z_2)   =        -1431.56 +/-  0.32 (still evaluating)
# log(Z_3)   =        -1431.97 +/-  0.32 (still evaluating)
# log(Z_4)   =        -1433.01 +/-  0.32
#
#
#
# Last dead point: [ 6.83047741e+01  3.03580538e-01  1.47994280e+02  1.41899343e+03
#   8.78633703e-01  9.99832925e-01  6.96419462e-01 -1.41901529e+03
#  -1.41899343e+03]
# _____________________________
# lives      |  12 |  83 |   5 |
# phantoms   | 302 |1160 | 154 |
# posteriors |1558 |1586 |1545 |
# equals     | 331 | 332 | 331 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       5
# ndead      =                1705
# nposterior =                1705
# nequals    =                 202
# nlike      =              129749
# <nlike>    =         166.20   (          11.08 per slice )
# log(Z)     =        -1430.38 +/-  0.31
# log(Z_1)   =        -1431.43 +/-  0.32 (still evaluating)
# log(Z_2)   =        -1431.55 +/-  0.32 (still evaluating)
# log(Z_3)   =        -1431.96 +/-  0.32
# log(Z_4)   =        -1433.01 +/-  0.32
# log(Z_5)   =        -1433.12 +/-  0.32 (still evaluating)
#
#
#
# Last dead point: [ 6.81359515e+01  3.04814029e-01  1.48195872e+02  1.41898534e+03
#   8.78628694e-01  9.99833024e-01  6.95185971e-01 -1.41901443e+03
#  -1.41898534e+03]
# _______________________
# lives      |   3 |  97 |
# phantoms   | 130 |1351 |
# posteriors |1568 |1659 |
# equals     | 331 | 332 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                1794
# nposterior =                1794
# nequals    =                 202
# nlike      =              140736
# <nlike>    =         109.87   (           7.32 per slice )
# log(Z)     =        -1430.38 +/-  0.31
# log(Z_1)   =        -1431.43 +/-  0.32 (still evaluating)
# log(Z_2)   =        -1431.55 +/-  0.32 (still evaluating)
# log(Z_3)   =        -1431.96 +/-  0.32
# log(Z_4)   =        -1433.01 +/-  0.32
# log(Z_5)   =        -1433.11 +/-  0.32
#
#
#
# Last dead point: [ 6.83840696e+01  3.04313885e-01  1.47704319e+02  1.41897620e+03
#   8.78623033e-01  9.99833137e-01  6.95686115e-01 -1.41898581e+03
#  -1.41897620e+03]
#  ____________________________________________________
# |                                                    |
# | ndead  =         1911                              |
# | log(Z) =        -1430.37566 +/-            0.31296 |
# |____________________________________________________|

# %%
paramnames = [('H0','H_{0}'),('Om', r'\Omega_{m0}'),('rd','r_d (Mpc)'),('L',r'L'),('Ldof',r'L/Dof'),('p','p'),('Omega_Lambda', r'\Omega_{\Lambda0}')]
outputCCBAO.make_paramnames_files(paramnames)
outputCCBAOPP.make_paramnames_files(paramnames)

posteriorCCBAO = outputCCBAO.posterior
posteriorCCBAOPP = outputCCBAOPP.posterior
# Out:
# WARNING:root:outlier fraction 0.15338345864661654
# WARNING:root:outlier fraction 0.17394468704512372
# chains/CC + BAO.txt
# Removed no burn in
# chains/CC + BAO + PP.txt
# Removed no burn in

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAO], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['darkblue','red'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2'],title_limit=1)
g.export("fig_a.pdf")
# Out:
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAOPP], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['darkblue','red'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2 + PP'],title_limit=1)
g.export("fig_b.pdf")
# Out:
# WARNING:root:fine_bins not large enough to well sample smoothing scale - p
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAO,posteriorCCBAOPP], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['darkblue','red'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2', r'CC + DESI DR2 + PP'])
g.export("fig_c.pdf")
# Out:
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
def get_constraints(samples):
    for i, mean in enumerate(samples.getMeans()):
        upper = samples.confidence(i, upper=True, limfrac=0.05)
        #print("\nupper limit 95 C.L. = %f" % upper)
        lower = samples.confidence(i, upper=False, limfrac=0.05)
        #print("lower limit 95 C.L. = %f" % lower)
        print("%s = %f +/- %f +/- %f" % (samples.parLabel(i),\

        mean, mean - samples.confidence(i, limfrac=0.16),\
        mean - samples.confidence(i, limfrac=0.025)) )
    return
for i in ["CCBAO",'CCBAOPP']:
    print(i)
    get_constraints(eval("posterior"+i))
# Out:
# CCBAO
# H_{0} = 68.527539 +/- 2.315792 +/- 5.167965
# \Omega_{m0} = 0.298279 +/- 0.005705 +/- 0.012139
# r_d (Mpc) = 148.281002 +/- 5.145444 +/- 9.824206
# L = 17.956880 +/- 1.021552 +/- 1.306655
# L/Dof = 0.718275 +/- 0.040862 +/- 0.052266
# p = 0.840422 +/- 0.043945 +/- 0.163893
# \Omega_{\Lambda0} = 0.701721 +/- 0.005260 +/- 0.012345
# CCBAOPP
# H_{0} = 68.552498 +/- 2.606845 +/- 5.714304
# \Omega_{m0} = 0.304688 +/- 0.005416 +/- 0.011717
# r_d (Mpc) = 147.592160 +/- 6.326622 +/- 11.079650
# L = 1420.506523 +/- 1.145193 +/- 1.440386
# L/Dof = 0.879571 +/- 0.000709 +/- 0.000892
# p = 0.999813 +/- 0.000017 +/- 0.000049
# \Omega_{\Lambda0} = 0.695312 +/- 0.006157 +/- 0.011920

# %% [markdown]
# ### Here We Compute The Log Of Bayesian Evidence

# %%
outputCCBAO
# Out:
# Global evidence:
# log(Z)    -26.884098 +/-  0.321147
#
# Local evidences:
# log(Z_1)    -63.460826 +/-  0.789161
# log(Z_2)    -33.633624 +/-  0.503929
# log(Z_3)    -31.672275 +/-  0.473045
# log(Z_4)    -31.859472 +/-  0.561980
# log(Z_5)    -31.357078 +/-  0.565921
# log(Z_6)    -29.849818 +/-  0.490626
# log(Z_7)    -30.078407 +/-  0.500843
# log(Z_8)    -29.179228 +/-  0.477894
# log(Z_9)    -27.166914 +/-  0.357086
#
# Run-time information:
# ncluster           9
# nposterior      1844
# nequals           98
# ndead           1844
# nlive              0
# nlike         157159
# <nlike>        [0.0]
#
# Parameter estimates:
# H0            H_{0}                6.852E+01 +/- 2.531E+00
# Om            \Omega_{m0}          2.984E-01 +/- 5.809E-03
# rd            r_d (Mpc)            1.483E+02 +/- 5.568E+00
# L             L                    1.790E+01 +/- 1.096E+00
# Ldof          L/Dof                7.158E-01 +/- 4.386E-02
# p             p                    8.436E-01 +/- 5.086E-02
# Omega_Lambda  \Omega_{\Lambda0}    7.016E-01 +/- 5.809E-03

# %%
outputCCBAOPP
# Out:
# Global evidence:
# log(Z)    -1430.375655 +/-  0.312961
#
# Local evidences:
# log(Z_1)    -1433.011575 +/-  0.320630
# log(Z_2)    -1431.962278 +/-  0.317968
# log(Z_3)    -1433.114540 +/-  0.324102
# log(Z_4)    -1431.552645 +/-  0.316313
# log(Z_5)    -1431.426845 +/-  0.315775
#
# Run-time information:
# ncluster           5
# nposterior      1911
# nequals          203
# ndead           1911
# nlive              0
# nlike         142483
# <nlike>        [0.0]
#
# Parameter estimates:
# H0            H_{0}                6.852E+01 +/- 2.931E+00
# Om            \Omega_{m0}          3.046E-01 +/- 5.552E-03
# rd            r_d (Mpc)            1.477E+02 +/- 6.406E+00
# L             L                    1.420E+03 +/- 1.202E+00
# Ldof          L/Dof                8.796E-01 +/- 7.440E-04
# p             p                    9.998E-01 +/- 1.727E-05
# Omega_Lambda  \Omega_{\Lambda0}    6.954E-01 +/- 5.552E-03

# %% [markdown]
# $\Large \textbf{Union3}$
#
# $\textbf{Source Link:}$ https://github.com/dscolnic/Pantheon
#
# $\textbf{Dataset Link:}$ https://github.com/CobayaSampler/sn_data/tree/master/Union3
#
# In this analysis, I use the full $\texttt{STAT+SYS}$ covariance matrix in this analysis.
#
#
# ### Citation Guidelines
#
# If you use this dataset in your work, please cite the following:
#
# - **Unin3 (2025)** : _Union Through UNITY: Cosmology with 2,000 SNe Using a Unified Bayesian Framework_ : [arXiv:2311.12098](
#   https://doi.org/10.48550/arXiv.2311.12098)

# %%
#Load Union3 dataset and Build the Covariance Matrix
values_filename = 'data/lcparam_full.txt'
cov_filename = 'data/mag_covmat.txt'

da = np.loadtxt(values_filename, skiprows=1, usecols=(1, 2, 4))
zcmb = da[:, 0]
zhelio = da[:, 1]
mag = da[:, 2]
N = len(mag)
syscov = np.loadtxt(cov_filename, skiprows=1).reshape((N, N))
cov = np.copy(syscov)
#self.cov[np.diag_indices_from(self.cov)] += self.dmag**2
xdiag = 1/cov.diagonal()  # diagonal before marginalising constant
# add marginalising over a constant
cov += 3**2
zmin = zcmb.min()
zmax = zcmb.max()
zmaxi = 1.1 ## we interpolate to 1.1 beyond that exact calc
print("Union3 : zmin=%f zmax=%f N=%i" % (zmin, zmax, N))
ninterp=150
zinter = np.linspace(1e-3, zmaxi, ninterp)
icov = la.inv(cov)
# Out:
# Union3 : zmin=0.050000 zmax=2.262260 N=22

# %%
def A(theta, x, y, icov):
    Mu = mu(theta, x)
    residual = y - Mu
    chit2 = residual.T @ icov @ residual
    B = np.sum(residual @ icov)
    C = np.sum(icov)
    chi2 = chit2 - (B**2 / C) + np.log(C / (2 * np.pi))
    return chi2

def lnlikeUnion3(theta):
    chi = A(theta, zcmb, mag, icov)
    i = len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeUnion3([67,0.32,147]))
# Out:
# (np.float64(-21.796588352588042), [np.float64(21.796588352588042), np.float64(1.1471888606625285), np.float64(0.2944964298435686), 0.6799999999999999])

# %%
def lnlikeCCBAOUnion3(theta):

    chi = lnlikecov(theta, funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv)
    i = len(BaoData[:, 0])
    chi += lnlike(theta, H, z, Hz, cov_mat_cc); i += len(z)
    chi += A(theta, zcmb, mag, icov);i += len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1 - stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeCCBAOUnion3([67,0.32,147]))
# Out:
# (np.float64(-68.53523241136814), [np.float64(68.53523241136814), np.float64(1.4581964342844285), np.float64(0.021814800088659436), 0.6799999999999999])

# %%
runs = 100

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
def uniprior(hypercube):
    prior = []
    prior.append(UniformPrior(50.,100.)(hypercube[0]))
    prior.append(UniformPrior(0.,1.)(hypercube[1]))
    prior.append(UniformPrior(100.,200.)(hypercube[2]))
    return prior

# %%
settingsCCBAOUnion3 = PolyChordSettings(3,4)
settingsCCBAOUnion3.file_root = 'CC + DESI DR2 + Union3'
settingsCCBAOUnion3.nlive = runs
settingsCCBAOUnion3.do_clustering = True
settingsCCBAOUnion3.read_resume = False

# %%
outputCCBAOUnion3 = pypolychord.run_polychord(lnlikeCCBAO, 3,4, settingsCCBAOUnion3, uniprior, dumper)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     100
# nDims    :       3
# nDerived :       4
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/CC + BAO.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.910E-03 seconds
# number of repeats:           15
# started sampling
#
# Last dead point: [ 6.44449960e+01  1.26587432e-01  1.59297606e+02  5.31687214e+03
#   2.12674886e+02  0.00000000e+00  8.73412568e-01 -1.00000000e+30
#  -5.31687214e+03]
# ________________
# lives      |100 |
# phantoms   |872 |
# posteriors |101 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 101
# nposterior =                 101
# nequals    =                   1
# nlike      =                2541
# <nlike>    =          24.41   (           1.63 per slice )
# log(Z)     =        -5322.83 +/-  0.83
# log(Z_1)   =        -5322.83 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 7.28817953e+01  3.40275350e-01  1.22145516e+02  1.48182735e+03
#   5.92730939e+01  0.00000000e+00  6.59724650e-01 -3.63937506e+03
#  -1.48182735e+03]
# _________________
# lives      | 100 |
# phantoms   |1293 |
# posteriors | 202 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 202
# nposterior =                 202
# nequals    =                   1
# nlike      =                6846
# <nlike>    =          43.05   (           2.87 per slice )
# log(Z)     =        -1488.79 +/-  0.84
# log(Z_1)   =        -1488.79 +/-  0.84 (still evaluating)
#
#
#
# Last dead point: [ 5.66534621e+01  6.05608616e-01  1.52670386e+02  5.98022629e+02
#   2.39209052e+01  0.00000000e+00  3.94391384e-01 -4.26997462e+03
#  -5.98022629e+02]
# _________________
# lives      | 100 |
# phantoms   |1403 |
# posteriors | 303 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 303
# nposterior =                 303
# nequals    =                   1
# nlike      =               11691
# <nlike>    =          48.45   (           3.23 per slice )
# log(Z)     =         -606.00 +/-  0.84
# log(Z_1)   =         -606.00 +/-  0.84 (still evaluating)
#
#
#
# Last dead point: [ 5.04661556e+01  4.45193466e-01  1.85350602e+02  2.42154988e+02
#   9.68619954e+00  0.00000000e+00  5.54806534e-01 -1.44201987e+04
#  -2.42154988e+02]
# _________________
# lives      | 100 |
# phantoms   |1420 |
# posteriors | 404 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 404
# nposterior =                 404
# nequals    =                   2
# nlike      =               17064
# <nlike>    =          53.73   (           3.58 per slice )
# log(Z)     =         -250.38 +/-  0.64
# log(Z_1)   =         -250.38 +/-  0.64 (still evaluating)
#
#
#
# Last dead point: [ 6.56547451e+01  3.56296959e-01  1.45319363e+02  1.05962965e+02
#   4.23851860e+00  6.09778894e-12  6.43703041e-01 -1.22273070e+02
#  -1.05962965e+02]
# _________________
# lives      | 100 |
# phantoms   |1539 |
# posteriors | 505 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 505
# nposterior =                 505
# nequals    =                   3
# nlike      =               22858
# <nlike>    =          57.94   (           3.86 per slice )
# log(Z)     =         -115.05 +/-  0.57
# log(Z_1)   =         -115.05 +/-  0.57 (still evaluating)
#
#
#
# Last dead point: [ 7.35800107e+01  2.49069100e-01  1.44241158e+02  5.83704604e+01
#   2.33481842e+00  1.74673267e-04  7.50930900e-01 -6.05271667e+01
#  -5.83704604e+01]
# _____________________
# lives      | 54 | 46 |
# phantoms   |909 |708 |
# posteriors |552 |561 |
# equals     |  5 |  4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 608
# nposterior =                 608
# nequals    =                   9
# nlike      =               32171
# <nlike>    =          93.13   (           6.21 per slice )
# log(Z)     =          -66.88 +/-  0.35
# log(Z_1)   =          -67.50 +/-  0.45 (still evaluating)
# log(Z_2)   =          -67.73 +/-  0.43 (still evaluating)
#
#
#
# Last dead point: [ 6.75352775e+01  2.73798006e-01  1.52135732e+02  3.22538750e+01
#   1.29015500e+00  1.50796907e-01  7.26201994e-01 -5.78617244e+01
#  -3.22538750e+01]
# __________________________
# lives      | 66 | 10 | 24 |
# phantoms   |847 |100 |331 |
# posteriors |614 |578 |585 |
# equals     |  8 |  1 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 711
# nposterior =                 711
# nequals    =                   4
# nlike      =               42926
# <nlike>    =         107.55   (           7.17 per slice )
# log(Z)     =          -42.04 +/-  0.36
# log(Z_1)   =          -42.19 +/-  0.39 (still evaluating)
# log(Z_2)   =          -44.45 +/-  0.64 (still evaluating)
# log(Z_3)   =          -45.97 +/-  0.85 (still evaluating)
#
#
#
# Last dead point: [ 75.12270804   0.31484822 133.77581239  24.70142226   0.98805689
#    0.47920288   0.68515178 -30.50541765 -24.70142226]
# _______________________
# lives      |  72 |  28 |
# phantoms   |1110 | 370 |
# posteriors | 687 | 603 |
# equals     |  23 |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                 814
# nposterior =                 814
# nequals    =                  13
# nlike      =               53843
# <nlike>    =         109.17   (           7.28 per slice )
# log(Z)     =          -34.34 +/-  0.31
# log(Z_1)   =          -34.66 +/-  0.33 (still evaluating)
# log(Z_2)   =          -35.91 +/-  0.48 (still evaluating)
# log(Z_3)   =          -37.62 +/-  0.53
#
#
#
# Last dead point: [ 76.2350956    0.29883235 132.80443275  20.73023771   0.82920951
#    0.70755096   0.70116765 -21.3292568  -20.73023771]
# ___________________________________
# lives      |  33 |   1 |   4 |  62 |
# phantoms   | 582 |  46 | 160 |1031 |
# posteriors | 643 | 694 | 696 | 725 |
# equals     |  22 |   6 |   5 |  19 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       4 /       7
# ndead      =                 917
# nposterior =                 917
# nequals    =                  44
# nlike      =               70015
# <nlike>    =         161.72   (          10.78 per slice )
# log(Z)     =          -30.60 +/-  0.30
# log(Z_1)   =          -31.30 +/-  0.38 (still evaluating)
# log(Z_2)   =          -31.77 +/-  0.35 (still evaluating)
# log(Z_3)   =          -33.06 +/-  0.45 (still evaluating)
# log(Z_4)   =          -33.63 +/-  0.45
# log(Z_5)   =          -34.39 +/-  0.47 (still evaluating)
# log(Z_6)   =          -35.33 +/-  0.47
# log(Z_7)   =          -37.62 +/-  0.53
#
#
#
# Last dead point: [ 72.62095261   0.29919608 139.21221695  18.81789373   0.75271575
#    0.80576749   0.70080392 -24.27566565 -18.81789373]
# _____________________________
# lives      |  14 |   4 |  82 |
# phantoms   | 281 | 102 |1392 |
# posteriors | 676 | 703 | 781 |
# equals     |  18 |   7 |  53 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       7
# ndead      =                1014
# nposterior =                1014
# nequals    =                  49
# nlike      =               83568
# <nlike>    =         135.53   (           9.04 per slice )
# log(Z)     =          -28.99 +/-  0.30
# log(Z_1)   =          -29.81 +/-  0.34 (still evaluating)
# log(Z_2)   =          -29.90 +/-  0.39 (still evaluating)
# log(Z_3)   =          -31.26 +/-  0.46 (still evaluating)
# log(Z_4)   =          -33.51 +/-  0.64
# log(Z_5)   =          -33.63 +/-  0.45
# log(Z_6)   =          -35.33 +/-  0.47
# log(Z_7)   =          -37.62 +/-  0.53
#
#
#
# Last dead point: [ 71.19191835   0.29480494 142.60671909  17.70716912   0.70828676
#    0.85456603   0.70519506 -21.42301196 -17.70716912]
# _______________________
# lives      |   1 |  99 |
# phantoms   |  43 |1350 |
# posteriors | 690 | 846 |
# equals     |  10 | 104 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       7
# ndead      =                1097
# nposterior =                1097
# nequals    =                  45
# nlike      =               91499
# <nlike>    =          79.31   (           5.29 per slice )
# log(Z)     =          -28.23 +/-  0.30
# log(Z_1)   =          -28.91 +/-  0.34 (still evaluating)
# log(Z_2)   =          -29.21 +/-  0.40 (still evaluating)
# log(Z_3)   =          -30.73 +/-  0.46
# log(Z_4)   =          -33.51 +/-  0.64
# log(Z_5)   =          -33.63 +/-  0.45
# log(Z_6)   =          -35.33 +/-  0.47
# log(Z_7)   =          -37.62 +/-  0.53
#
#
#
# Last dead point: [ 65.5259746    0.29794652 154.83658741  17.23796801   0.68951872
#    0.87298191   0.70205348 -17.80947336 -17.23796801]
# _________________
# lives      | 100 |
# phantoms   |1480 |
# posteriors | 937 |
# equals     | 172 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       7
# ndead      =                1189
# nposterior =                1189
# nequals    =                  46
# nlike      =               98442
# <nlike>    =          69.43   (           4.63 per slice )
# log(Z)     =          -27.89 +/-  0.30
# log(Z_1)   =          -28.36 +/-  0.34 (still evaluating)
# log(Z_2)   =          -29.14 +/-  0.41
# log(Z_3)   =          -30.73 +/-  0.46
# log(Z_4)   =          -33.51 +/-  0.64
# log(Z_5)   =          -33.63 +/-  0.45
# log(Z_6)   =          -35.33 +/-  0.47
# log(Z_7)   =          -37.62 +/-  0.53
#
#
#
# Last dead point: [ 69.99310696   0.29940902 145.02554109  16.91729202   0.67669168
#    0.88477174   0.70059098 -17.13172358 -16.91729202]
# _________________
# lives      | 100 |
# phantoms   |1434 |
# posteriors |1038 |
# equals     | 219 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       7
# ndead      =                1290
# nposterior =                1290
# nequals    =                  55
# nlike      =              105750
# <nlike>    =          73.08   (           4.87 per slice )
# log(Z)     =          -27.73 +/-  0.31
# log(Z_1)   =          -28.12 +/-  0.34 (still evaluating)
# log(Z_2)   =          -29.14 +/-  0.41
# log(Z_3)   =          -30.73 +/-  0.46
# log(Z_4)   =          -33.51 +/-  0.64
# log(Z_5)   =          -33.63 +/-  0.45
# log(Z_6)   =          -35.33 +/-  0.47
# log(Z_7)   =          -37.62 +/-  0.53
#
#
#
# Last dead point: [ 69.74393559   0.29956668 145.27038458  16.74070057   0.66962802
#    0.89098281   0.70043332 -16.82911818 -16.74070057]
# _________________
# lives      | 100 |
# phantoms   |1346 |
# posteriors |1139 |
# equals     | 238 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       7
# ndead      =                1391
# nposterior =                1391
# nequals    =                  58
# nlike      =              112973
# <nlike>    =          72.23   (           4.82 per slice )
# log(Z)     =          -27.66 +/-  0.31
# log(Z_1)   =          -28.02 +/-  0.34 (still evaluating)
# log(Z_2)   =          -29.14 +/-  0.41
# log(Z_3)   =          -30.73 +/-  0.46
# log(Z_4)   =          -33.51 +/-  0.64
# log(Z_5)   =          -33.63 +/-  0.45
# log(Z_6)   =          -35.33 +/-  0.47
# log(Z_7)   =          -37.62 +/-  0.53
#
#
#
# Last dead point: [ 68.7562094    0.29554147 147.85144233  16.6645425    0.6665817
#    0.89359926   0.70445853 -16.96293889 -16.6645425 ]
# _________________
# lives      | 100 |
# phantoms   |1431 |
# posteriors |1240 |
# equals     | 247 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       7
# ndead      =                1492
# nposterior =                1492
# nequals    =                  59
# nlike      =              120287
# <nlike>    =          73.14   (           4.88 per slice )
# log(Z)     =          -27.64 +/-  0.31
# log(Z_1)   =          -27.99 +/-  0.35 (still evaluating)
# log(Z_2)   =          -29.14 +/-  0.41
# log(Z_3)   =          -30.73 +/-  0.46
# log(Z_4)   =          -33.51 +/-  0.64
# log(Z_5)   =          -33.63 +/-  0.45
# log(Z_6)   =          -35.33 +/-  0.47
# log(Z_7)   =          -37.62 +/-  0.53
#
#
#
# Last dead point: [ 69.01272792   0.29911676 146.89575531  16.62208189   0.66488328
#    0.89504169   0.70088324 -16.68153499 -16.62208189]
# _________________
# lives      | 100 |
# phantoms   |1440 |
# posteriors |1341 |
# equals     | 250 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       7
# ndead      =                1593
# nposterior =                1593
# nequals    =                  61
# nlike      =              127562
# <nlike>    =          72.75   (           4.85 per slice )
# log(Z)     =          -27.63 +/-  0.31
# log(Z_1)   =          -27.97 +/-  0.35 (still evaluating)
# log(Z_2)   =          -29.14 +/-  0.41
# log(Z_3)   =          -30.73 +/-  0.46
# log(Z_4)   =          -33.51 +/-  0.64
# log(Z_5)   =          -33.63 +/-  0.45
# log(Z_6)   =          -35.33 +/-  0.47
# log(Z_7)   =          -37.62 +/-  0.53
#
#
#
# Last dead point: [ 69.10742487   0.29676589 147.00240507  16.60200795   0.66408032
#    0.89571955   0.70323411 -16.63748627 -16.60200795]
# _________________
# lives      | 100 |
# phantoms   |1487 |
# posteriors |1442 |
# equals     | 251 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       7
# ndead      =                1694
# nposterior =                1694
# nequals    =                  61
# nlike      =              134898
# <nlike>    =          73.36   (           4.89 per slice )
# log(Z)     =          -27.62 +/-  0.31
# log(Z_1)   =          -27.97 +/-  0.35 (still evaluating)
# log(Z_2)   =          -29.14 +/-  0.41
# log(Z_3)   =          -30.73 +/-  0.46
# log(Z_4)   =          -33.51 +/-  0.64
# log(Z_5)   =          -33.63 +/-  0.45
# log(Z_6)   =          -35.33 +/-  0.47
# log(Z_7)   =          -37.62 +/-  0.53
#
#
#
# Last dead point: [ 68.65435135   0.29786785 147.85398581  16.57715365   0.66308615
#    0.89655521   0.70213215 -16.59567106 -16.57715365]
#  ____________________________________________________
# |                                                    |
# | ndead  =         1876                              |
# | log(Z) =          -27.62104 +/-            0.31010 |
# |____________________________________________________|

# %%
paramnames = [('H0','H_{0}'),('Om', r'\Omega_{m0}'),('rd','r_d (Mpc)'),('L',r'L'),('Ldof',r'L/Dof'),('p','p'),('Omega_Lambda', r'\Omega_{\Lambda0}')]
outputCCBAOUnion3.make_paramnames_files(paramnames)

posteriorCCBAOUnion3 = outputCCBAOUnion3.posterior
# Out:
# WARNING:root:outlier fraction 0.15066469719350073
# chains/CC + BAO.txt
# Removed no burn in

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAOUnion3], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['darkblue','red'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2 + Union3'],title_limit=1)
g.export("fig_d.pdf")
# Out:
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAO,posteriorCCBAOPP,posteriorCCBAOUnion3], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['darkblue','red', 'purple'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2', r'CC + DESI DR2 + PP',r'CC + DESI DR2 + Union3'])
g.export("fig_d.pdf")
# Out:
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
def get_constraints(samples):
    for i, mean in enumerate(samples.getMeans()):
        upper = samples.confidence(i, upper=True, limfrac=0.05)
        #print("\nupper limit 95 C.L. = %f" % upper)
        lower = samples.confidence(i, upper=False, limfrac=0.05)
        #print("lower limit 95 C.L. = %f" % lower)
        print("%s = %f +/- %f +/- %f" % (samples.parLabel(i),\

        mean, mean - samples.confidence(i, limfrac=0.16),\
        mean - samples.confidence(i, limfrac=0.025)) )
    return
for i in ['CCBAOUnion3']:
    print(i)
    get_constraints(eval("posterior"+i))
# Out:
# CCBAOUnion3
# H_{0} = 69.059552 +/- 3.127966 +/- 5.653851
# \Omega_{m0} = 0.297978 +/- 0.005977 +/- 0.011141
# r_d (Mpc) = 147.243784 +/- 6.708563 +/- 11.489223
# L = 18.194375 +/- 1.116548 +/- 1.500369
# L/Dof = 0.727775 +/- 0.044662 +/- 0.060015
# p = 0.829921 +/- 0.051550 +/- 0.159887
# \Omega_{\Lambda0} = 0.702022 +/- 0.006555 +/- 0.012660

# %%
outputCCBAOUnion3
# Out:
# Global evidence:
# log(Z)    -27.621043 +/-  0.310103
#
# Local evidences:
# log(Z_1)    -37.615233 +/-  0.531211
# log(Z_2)    -35.327966 +/-  0.468668
# log(Z_3)    -33.634850 +/-  0.452087
# log(Z_4)    -33.505736 +/-  0.638739
# log(Z_5)    -30.728580 +/-  0.458922
# log(Z_6)    -29.136632 +/-  0.405595
# log(Z_7)    -27.962631 +/-  0.345686
#
# Run-time information:
# ncluster           7
# nposterior      1876
# nequals           61
# ndead           1876
# nlive              0
# nlike         140883
# <nlike>        [0.0]
#
# Parameter estimates:
# H0            H_{0}                6.973E+01 +/- 2.691E+00
# Om            \Omega_{m0}          2.990E-01 +/- 7.359E-03
# rd            r_d (Mpc)            1.456E+02 +/- 5.624E+00
# L             L                    1.837E+01 +/- 1.520E+00
# Ldof          L/Dof                7.350E-01 +/- 6.078E-02
# p             p                    8.205E-01 +/- 7.422E-02
# Omega_Lambda  \Omega_{\Lambda0}    7.010E-01 +/- 7.359E-03

# %% [markdown]
# $\Large \textbf{Dark Energy Survey Supernova}$
#
# $\textbf{Source Link:}$ https://github.com/des-science/DES-SN5YR/blob/main/5_COSMOLOGY/SN_only_cosmosis_likelihood.py
#
# $\textbf{Dataset Link:}$ https://github.com/des-science/DES-SN5YR/tree/main/4_DISTANCES_COVMAT
#
# In this analysis, I use the full $\texttt{STAT+SYS}$ covariance matrix in this analysis.

# %%
#Load DES_SN_5Y dataset and Build the Covariance Matrix
values_filename = 'data/DES-SN5YR_HD.csv'
cov_filename = 'data/covsys_000.txt'

da = pd.read_csv(values_filename)
zcmb = da['zHD']
zhelio = da['zHEL']
mag = da['MU']
dmag = da['MUERR_FINAL']
N = len(mag)
syscov = np.loadtxt(cov_filename, skiprows=1).reshape((N, N))
cov = np.copy(syscov)
cov[np.diag_indices_from(cov)] += dmag**2
xdiag = 1/cov.diagonal()  # diagonal before marginalising constant
        # add marginalising over a constant
cov += 3**2
zmin = zcmb.min()
zmax = zcmb.max()
zmaxi = 1.1 ## we interpolate to 1.1 beyond that exact calc
print("DESY5: zmin=%f zmax=%f N=%i" % (zmin, zmax, N))
ninterp=150
zinter = np.linspace(1e-3, zmaxi, ninterp)
icov = la.inv(cov)
# Out:
# DESY5: zmin=0.025090 zmax=1.121320 N=1829

# %%
def chiInt_DES(theta, z):
    H0, Om, rd = theta
    z = np.array(z)
    z_sorted_unique = np.sort(np.unique(z))
    z_integrate = np.hstack((np.array([0]), z_sorted_unique))
    arr = odeint(dchidz, 0, z_integrate, args=(H0, Om, rd))
    chi_sorted = np.delete(arr, 0)
    chi_original_order = np.interp(z, z_sorted_unique, chi_sorted)
    return chi_original_order
chiInt_DES([67, 0.32, 147], [1, 2, 3])
# Out:
# array([0.7624812 , 1.18936468, 1.45585048])

# %%
def DL(theta,z):
    H0, Om, rd = theta
    chi = chiInt_DES(theta,z)
    return c*chi/H0

def mu(theta,z):
    H0, Om, rd = theta
    dL = DL(theta,z)
    mu = []

    for i in range(len(z)):
        mu.append(5*np.log10(dL[i]*(1+z[i])) + 25)
    mu = np.array(mu)
    mu.shape
    return mu

# %%
def A(theta, x, y, icov):
    Mu = mu(theta, x)
    residual = y - Mu
    chit2 = residual.T @ icov @ residual
    B = np.sum(residual @ icov)
    C = np.sum(icov)
    chi2 = chit2 - (B**2 / C) + np.log(C / (2 * np.pi))
    return chi2

def lnlikeDESSN5YR(theta):
    chi = A(theta, zcmb, mag, icov)
    i = len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeDESSN5YR([67,0.32,147]))
# Out:
# (np.float64(-1639.5712226217324), [np.float64(1639.5712226217324), np.float64(0.8979031887304121), np.float64(0.9992775762674531), 0.6799999999999999])

# %%
def lnlikeCCBAODESSN5YR(theta):

    chi = lnlikecov(theta, funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv)
    i = len(BaoData[:, 0])
    chi += lnlike(theta, H, z, Hz, cov_mat_cc); i += len(z)
    chi += A(theta, zcmb, mag, icov);i += len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1 - stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeCCBAODESSN5YR([67,0.32,147]))
# Out:
# (np.float64(-1686.3098666805126), [np.float64(1686.3098666805126), np.float64(0.9095522474004922), np.float64(0.9976762520037377), 0.6799999999999999])

# %%
runs = 100

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
def uniprior(hypercube):
    prior = []
    prior.append(UniformPrior(50.,100.)(hypercube[0]))
    prior.append(UniformPrior(0.,1.)(hypercube[1]))
    prior.append(UniformPrior(100.,200.)(hypercube[2]))
    return prior

# %%
settingsCCBAODESSN5YR = PolyChordSettings(3,4)
settingsCCBAODESSN5YR.file_root = 'CC + DESI DR2 + DES SN5YR'
settingsCCBAODESSN5YR.nlive = runs
settingsCCBAODESSN5YR.do_clustering = True
settingsCCBAODESSN5YR.read_resume = False

# %%
outputCCBAODESSN5YR = pypolychord.run_polychord(lnlikeCCBAODESSN5YR, 3,4, settingsCCBAODESSN5YR, uniprior, dumper)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.1
#   release: 10th Jan 2024
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     100
# nDims    :       3
# nDerived :       4
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/CC + BAO + DES SN5YR.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.773E-02 seconds
# number of repeats:           15
# started sampling
#
# Last dead point: [ 6.05147760e+01  3.02549290e-01  1.38106405e+02  7.42407416e+03
#   4.00435499e+00  0.00000000e+00  6.97450710e-01 -7.99828356e+03
#  -7.42407416e+03]
# ________________
# lives      |100 |
# phantoms   |820 |
# posteriors |101 |
# equals     |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 101
# nposterior =                 101
# nequals    =                   1
# nlike      =                2494
# <nlike>    =          23.94   (           1.60 per slice )
# log(Z)     =        -7430.00 +/-  0.82
# log(Z_1)   =        -7430.00 +/-  0.82 (still evaluating)
#
#
#
# Last dead point: [ 7.08221022e+01  1.20627472e-01  1.83666568e+02  3.41178993e+03
#   1.84023189e+00  0.00000000e+00  8.79372528e-01 -3.59423536e+03
#  -3.41178993e+03]
# _________________
# lives      | 100 |
# phantoms   |1195 |
# posteriors | 202 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 202
# nposterior =                 202
# nequals    =                   1
# nlike      =                7018
# <nlike>    =          45.24   (           3.02 per slice )
# log(Z)     =        -3418.71 +/-  0.82
# log(Z_1)   =        -3418.71 +/-  0.82 (still evaluating)
#
#
#
# Last dead point: [ 5.26539950e+01  4.57304983e-01  1.63810339e+02  2.38226536e+03
#   1.28493277e+00  7.77156117e-16  5.42695017e-01 -2.47280758e+03
#  -2.38226536e+03]
# _______________________
# lives      |  98 |   2 |
# phantoms   |1444 |  42 |
# posteriors | 301 | 205 |
# equals     |   1 |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 304
# nposterior =                 304
# nequals    =                   1
# nlike      =               12292
# <nlike>    =          52.74   (           3.52 per slice )
# log(Z)     =        -2390.28 +/-  0.84
# log(Z_1)   =        -2390.28 +/-  0.84 (still evaluating)
# log(Z_2)   =        -2489.66 +/-  0.76 (still evaluating)
#
#
#
# Last dead point: [ 7.44063424e+01  4.43790920e-01  1.26512305e+02  1.92765205e+03
#   1.03972603e+00  1.14143606e-01  5.56209080e-01 -2.12155352e+03
#  -1.92765205e+03]
# _________________
# lives      | 100 |
# phantoms   |1464 |
# posteriors | 396 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                 401
# nposterior =                 401
# nequals    =                   1
# nlike      =               17750
# <nlike>    =          54.58   (           3.64 per slice )
# log(Z)     =        -1936.54 +/-  0.81
# log(Z_1)   =        -1936.54 +/-  0.81 (still evaluating)
# log(Z_2)   =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 6.43539688e+01  3.42010361e-01  1.48841114e+02  1.76353396e+03
#   9.51204940e-01  9.33131883e-01  6.57989639e-01 -1.91525088e+03
#  -1.76353396e+03]
# _________________
# lives      | 100 |
# phantoms   |1451 |
# posteriors | 497 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                 502
# nposterior =                 502
# nequals    =                   1
# nlike      =               23517
# <nlike>    =          57.67   (           3.84 per slice )
# log(Z)     =        -1772.96 +/-  0.66
# log(Z_1)   =        -1772.96 +/-  0.66 (still evaluating)
# log(Z_2)   =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 7.14935125e+01  3.23938490e-01  1.41827924e+02  1.70852324e+03
#   9.21533571e-01  9.92727874e-01  6.76061510e-01 -1.89085072e+03
#  -1.70852324e+03]
# __________________________
# lives      | 48 | 41 | 11 |
# phantoms   |708 |759 |137 |
# posteriors |532 |549 |504 |
# equals     |  1 |  4 |  1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       5
# ndead      =                 604
# nposterior =                 604
# nequals    =                   4
# nlike      =               33694
# <nlike>    =         101.77   (           6.78 per slice )
# log(Z)     =        -1717.97 +/-  0.47
# log(Z_1)   =        -1718.39 +/-  0.50 (still evaluating)
# log(Z_2)   =        -1719.41 +/-  0.85
# log(Z_3)   =        -1721.78 +/-  0.66 (still evaluating)
# log(Z_4)   =        -1724.29 +/-  0.84 (still evaluating)
# log(Z_5)   =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 5.75913574e+01  3.36731023e-01  1.70231755e+02  1.68204209e+03
#   9.07250320e-01  9.98165148e-01  6.63268977e-01 -1.68319468e+03
#  -1.68204209e+03]
# __________________________
# lives      | 61 | 35 |  4 |
# phantoms   |991 |588 | 97 |
# posteriors |578 |593 |517 |
# equals     |  5 |  3 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       5
# ndead      =                 707
# nposterior =                 707
# nequals    =                   9
# nlike      =               45107
# <nlike>    =         114.13   (           7.61 per slice )
# log(Z)     =        -1691.59 +/-  0.34
# log(Z_1)   =        -1692.06 +/-  0.40 (still evaluating)
# log(Z_2)   =        -1693.29 +/-  0.53 (still evaluating)
# log(Z_3)   =        -1693.51 +/-  0.53 (still evaluating)
# log(Z_4)   =        -1719.41 +/-  0.85
# log(Z_5)   =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 5.70145843e+01  3.14168405e-01  1.76494776e+02  1.67062579e+03
#   9.01092658e-01  9.99051161e-01  6.85831595e-01 -1.67324418e+03
#  -1.67062579e+03]
# ____________________________________
# lives      |  8 | 14 | 41 | 33 |  4 |
# phantoms   |140 |225 |704 |542 | 56 |
# posteriors |597 |585 |612 |616 |607 |
# equals     |  1 |  2 |  5 |  5 |  4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       5 /       8
# ndead      =                 810
# nposterior =                 810
# nequals    =                   8
# nlike      =               64316
# <nlike>    =         192.09   (          12.81 per slice )
# log(Z)     =        -1680.53 +/-  0.32
# log(Z_1)   =        -1681.90 +/-  0.46 (still evaluating)
# log(Z_2)   =        -1682.04 +/-  0.42 (still evaluating)
# log(Z_3)   =        -1682.09 +/-  0.50 (still evaluating)
# log(Z_4)   =        -1682.52 +/-  0.56 (still evaluating)
# log(Z_5)   =        -1682.73 +/-  0.59 (still evaluating)
# log(Z_6)   =        -1688.06 +/-  0.68
# log(Z_7)   =        -1719.41 +/-  0.85
# log(Z_8)   =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 5.91826910e+01  3.11632476e-01  1.69410288e+02  1.66639021e+03
#   8.98808094e-01  9.99264737e-01  6.88367524e-01 -1.67135724e+03
#  -1.66639021e+03]
# __________________________
# lives      |  7 | 41 | 52 |
# phantoms   |190 |816 |722 |
# posteriors |601 |647 |641 |
# equals     |  5 | 16 |  8 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       8
# ndead      =                 900
# nposterior =                 900
# nequals    =                  24
# nlike      =               80324
# <nlike>    =         160.08   (          10.67 per slice )
# log(Z)     =        -1676.63 +/-  0.31
# log(Z_1)   =        -1677.75 +/-  0.38 (still evaluating)
# log(Z_2)   =        -1677.86 +/-  0.42 (still evaluating)
# log(Z_3)   =        -1678.04 +/-  0.46 (still evaluating)
# log(Z_4)   =        -1679.18 +/-  0.45
# log(Z_5)   =        -1680.40 +/-  0.55
# log(Z_6)   =        -1688.06 +/-  0.68
# log(Z_7)   =        -1719.41 +/-  0.85
# log(Z_8)   =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 7.13192009e+01  3.02965146e-01  1.42233237e+02  1.66345442e+03
#   8.97224609e-01  9.99385901e-01  6.97034854e-01 -1.66362259e+03
#  -1.66345442e+03]
# __________________________
# lives      | 41 | 57 |  2 |
# phantoms   |718 |831 | 46 |
# posteriors |687 |693 |606 |
# equals     | 28 | 33 |  2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       9
# ndead      =                1000
# nposterior =                1000
# nequals    =                  33
# nlike      =               93540
# <nlike>    =         132.16   (           8.81 per slice )
# log(Z)     =        -1674.03 +/-  0.31
# log(Z_1)   =        -1674.83 +/-  0.40 (still evaluating)
# log(Z_2)   =        -1674.95 +/-  0.38 (still evaluating)
# log(Z_3)   =        -1676.37 +/-  0.55 (still evaluating)
# log(Z_4)   =        -1678.18 +/-  0.50
# log(Z_5)   =        -1679.18 +/-  0.45
# log(Z_6)   =        -1680.40 +/-  0.55
# log(Z_7)   =        -1688.06 +/-  0.68
# log(Z_8)   =        -1719.41 +/-  0.85
# log(Z_9)   =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 7.20499471e+01  3.06921109e-01  1.40163026e+02  1.66222765e+03
#   8.96562917e-01  9.99430874e-01  6.93078891e-01 -1.66313285e+03
#  -1.66222765e+03]
# _______________________
# lives      |  65 |  35 |
# phantoms   |1039 | 610 |
# posteriors | 745 | 718 |
# equals     |  67 |  44 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /      10
# ndead      =                1093
# nposterior =                1093
# nequals    =                  67
# nlike      =              107013
# <nlike>    =         134.73   (           8.98 per slice )
# log(Z)     =        -1673.05 +/-  0.31
# log(Z_1)   =        -1673.80 +/-  0.39 (still evaluating)
# log(Z_2)   =        -1674.19 +/-  0.38 (still evaluating)
# log(Z_3)   =        -1675.37 +/-  0.40
# log(Z_4)   =        -1675.78 +/-  0.55
# log(Z_5)   =        -1678.18 +/-  0.50
# log(Z_6)   =        -1679.18 +/-  0.45
# log(Z_7)   =        -1680.40 +/-  0.55
# log(Z_8)   =        -1688.06 +/-  0.68
# log(Z_9)   =        -1719.41 +/-  0.85
# log(Z_10)  =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 6.67537576e+01  3.15511452e-01  1.50206665e+02  1.66146281e+03
#   8.96150382e-01  9.99457362e-01  6.84488548e-01 -1.66170757e+03
#  -1.66146281e+03]
# _______________________
# lives      |  29 |  71 |
# phantoms   | 431 |1158 |
# posteriors | 753 | 802 |
# equals     |  76 | 109 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /      11
# ndead      =                1190
# nposterior =                1190
# nequals    =                 110
# nlike      =              120745
# <nlike>    =         137.32   (           9.15 per slice )
# log(Z)     =        -1672.53 +/-  0.32
# log(Z_1)   =        -1673.33 +/-  0.40 (still evaluating)
# log(Z_2)   =        -1673.58 +/-  0.38 (still evaluating)
# log(Z_3)   =        -1675.21 +/-  0.41
# log(Z_4)   =        -1675.37 +/-  0.40
# log(Z_5)   =        -1675.78 +/-  0.55
# log(Z_6)   =        -1678.18 +/-  0.50
# log(Z_7)   =        -1679.18 +/-  0.45
# log(Z_8)   =        -1680.40 +/-  0.55
# log(Z_9)   =        -1688.06 +/-  0.68
# log(Z_10)  =        -1719.41 +/-  0.85
# log(Z_11)  =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 6.87614623e+01  3.07190142e-01  1.46386802e+02  1.66108621e+03
#   8.95947257e-01  9.99469984e-01  6.92809858e-01 -1.66122722e+03
#  -1.66108621e+03]
# _______________________
# lives      |  83 |  17 |
# phantoms   |1152 | 373 |
# posteriors | 863 | 779 |
# equals     | 145 |  95 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /      12
# ndead      =                1286
# nposterior =                1286
# nequals    =                 138
# nlike      =              133940
# <nlike>    =         131.95   (           8.80 per slice )
# log(Z)     =        -1672.29 +/-  0.32
# log(Z_1)   =        -1673.07 +/-  0.40 (still evaluating)
# log(Z_2)   =        -1673.53 +/-  0.39 (still evaluating)
# log(Z_3)   =        -1674.79 +/-  0.40
# log(Z_4)   =        -1675.21 +/-  0.41
# log(Z_5)   =        -1675.37 +/-  0.40
# log(Z_6)   =        -1675.78 +/-  0.55
# log(Z_7)   =        -1678.18 +/-  0.50
# log(Z_8)   =        -1679.18 +/-  0.45
# log(Z_9)   =        -1680.40 +/-  0.55
# log(Z_10)  =        -1688.06 +/-  0.68
# log(Z_11)  =        -1719.41 +/-  0.85
# log(Z_12)  =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 6.83409416e+01  3.13468107e-01  1.46808236e+02  1.66093794e+03
#   8.95867283e-01  9.99474879e-01  6.86531893e-01 -1.66101334e+03
#  -1.66093794e+03]
# _____________________________
# lives      |  88 |   1 |  11 |
# phantoms   |1548 |  84 | 215 |
# posteriors | 950 | 788 | 786 |
# equals     | 164 |  97 |  98 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /      13
# ndead      =                1389
# nposterior =                1389
# nequals    =                 149
# nlike      =              144903
# <nlike>    =         109.63   (           7.31 per slice )
# log(Z)     =        -1672.20 +/-  0.32
# log(Z_1)   =        -1672.92 +/-  0.40 (still evaluating)
# log(Z_2)   =        -1674.03 +/-  0.39 (still evaluating)
# log(Z_3)   =        -1674.26 +/-  0.40 (still evaluating)
# log(Z_4)   =        -1674.79 +/-  0.40
# log(Z_5)   =        -1675.21 +/-  0.41
# log(Z_6)   =        -1675.37 +/-  0.40
# log(Z_7)   =        -1675.78 +/-  0.55
# log(Z_8)   =        -1678.18 +/-  0.50
# log(Z_9)   =        -1679.18 +/-  0.45
# log(Z_10)  =        -1680.40 +/-  0.55
# log(Z_11)  =        -1688.06 +/-  0.68
# log(Z_12)  =        -1719.41 +/-  0.85
# log(Z_13)  =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 6.88464663e+01  3.11931936e-01  1.45819630e+02  1.66084759e+03
#   8.95818549e-01  9.99477841e-01  6.88068064e-01 -1.66085857e+03
#  -1.66084759e+03]
# _____________________________
# lives      |  94 |   3 |   3 |
# phantoms   |1663 |  89 | 169 |
# posteriors |1023 | 960 | 790 |
# equals     | 173 | 165 |  99 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /      15
# ndead      =                1484
# nposterior =                1484
# nequals    =                 155
# nlike      =              156434
# <nlike>    =         115.31   (           7.69 per slice )
# log(Z)     =        -1672.16 +/-  0.32
# log(Z_1)   =        -1672.98 +/-  0.40 (still evaluating)
# log(Z_2)   =        -1674.25 +/-  0.40
# log(Z_3)   =        -1674.61 +/-  0.40 (still evaluating)
# log(Z_4)   =        -1674.74 +/-  0.40
# log(Z_5)   =        -1674.79 +/-  0.40
# log(Z_6)   =        -1675.11 +/-  0.41 (still evaluating)
# log(Z_7)   =        -1675.21 +/-  0.41
# log(Z_8)   =        -1675.37 +/-  0.40
# log(Z_9)   =        -1675.78 +/-  0.55
# log(Z_10)  =        -1678.18 +/-  0.50
# log(Z_11)  =        -1679.18 +/-  0.45
# log(Z_12)  =        -1680.40 +/-  0.55
# log(Z_13)  =        -1688.06 +/-  0.68
# log(Z_14)  =        -1719.41 +/-  0.85
# log(Z_15)  =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 6.88908427e+01  3.08667758e-01  1.46143901e+02  1.66079475e+03
#   8.95790051e-01  9.99479566e-01  6.91332242e-01 -1.66082118e+03
#  -1.66079475e+03]
# _________________
# lives      | 100 |
# phantoms   |1440 |
# posteriors |1104 |
# equals     | 174 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /      15
# ndead      =                1572
# nposterior =                1572
# nequals    =                 157
# nlike      =              163466
# <nlike>    =          70.32   (           4.69 per slice )
# log(Z)     =        -1672.15 +/-  0.32
# log(Z_1)   =        -1672.96 +/-  0.40 (still evaluating)
# log(Z_2)   =        -1674.25 +/-  0.40
# log(Z_3)   =        -1674.59 +/-  0.40
# log(Z_4)   =        -1674.74 +/-  0.40
# log(Z_5)   =        -1674.79 +/-  0.40
# log(Z_6)   =        -1675.10 +/-  0.41
# log(Z_7)   =        -1675.21 +/-  0.41
# log(Z_8)   =        -1675.37 +/-  0.40
# log(Z_9)   =        -1675.78 +/-  0.55
# log(Z_10)  =        -1678.18 +/-  0.50
# log(Z_11)  =        -1679.18 +/-  0.45
# log(Z_12)  =        -1680.40 +/-  0.55
# log(Z_13)  =        -1688.06 +/-  0.68
# log(Z_14)  =        -1719.41 +/-  0.85
# log(Z_15)  =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 6.82479098e+01  3.10964875e-01  1.47202237e+02  1.66076760e+03
#   8.95775406e-01  9.99480451e-01  6.89035125e-01 -1.66079160e+03
#  -1.66076760e+03]
# _________________
# lives      | 100 |
# phantoms   |1498 |
# posteriors |1205 |
# equals     | 178 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /      15
# ndead      =                1673
# nposterior =                1673
# nequals    =                 158
# nlike      =              170777
# <nlike>    =          73.11   (           4.87 per slice )
# log(Z)     =        -1672.14 +/-  0.32
# log(Z_1)   =        -1672.95 +/-  0.40 (still evaluating)
# log(Z_2)   =        -1674.25 +/-  0.40
# log(Z_3)   =        -1674.59 +/-  0.40
# log(Z_4)   =        -1674.74 +/-  0.40
# log(Z_5)   =        -1674.79 +/-  0.40
# log(Z_6)   =        -1675.10 +/-  0.41
# log(Z_7)   =        -1675.21 +/-  0.41
# log(Z_8)   =        -1675.37 +/-  0.40
# log(Z_9)   =        -1675.78 +/-  0.55
# log(Z_10)  =        -1678.18 +/-  0.50
# log(Z_11)  =        -1679.18 +/-  0.45
# log(Z_12)  =        -1680.40 +/-  0.55
# log(Z_13)  =        -1688.06 +/-  0.68
# log(Z_14)  =        -1719.41 +/-  0.85
# log(Z_15)  =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 6.85622991e+01  3.10478453e-01  1.46643036e+02  1.66075136e+03
#   8.95766648e-01  9.99480979e-01  6.89521547e-01 -1.66076228e+03
#  -1.66075136e+03]
# _______________________
# lives      |  20 |  80 |
# phantoms   | 348 |1261 |
# posteriors |1230 |1282 |
# equals     | 179 | 178 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /      16
# ndead      =                1775
# nposterior =                1775
# nequals    =                 158
# nlike      =              185086
# <nlike>    =         143.09   (           9.54 per slice )
# log(Z)     =        -1672.14 +/-  0.32
# log(Z_1)   =        -1673.36 +/-  0.40 (still evaluating)
# log(Z_2)   =        -1674.04 +/-  0.40 (still evaluating)
# log(Z_3)   =        -1674.25 +/-  0.40
# log(Z_4)   =        -1674.59 +/-  0.40
# log(Z_5)   =        -1674.74 +/-  0.40
# log(Z_6)   =        -1674.79 +/-  0.40
# log(Z_7)   =        -1675.10 +/-  0.41
# log(Z_8)   =        -1675.21 +/-  0.41
# log(Z_9)   =        -1675.37 +/-  0.40
# log(Z_10)  =        -1675.78 +/-  0.55
# log(Z_11)  =        -1678.18 +/-  0.50
# log(Z_12)  =        -1679.18 +/-  0.45
# log(Z_13)  =        -1680.40 +/-  0.55
# log(Z_14)  =        -1688.06 +/-  0.68
# log(Z_15)  =        -1719.41 +/-  0.85
# log(Z_16)  =        -2250.75 +/-  0.76
#
#
#
# Last dead point: [ 6.81559177e+01  3.09872819e-01  1.47566849e+02  1.66073622e+03
#   8.95758477e-01  9.99481472e-01  6.90127181e-01 -1.66077321e+03
#  -1.66073622e+03]
#  ____________________________________________________
# |                                                    |
# | ndead  =         1890                              |
# | log(Z) =        -1672.14113 +/-            0.32220 |
# |____________________________________________________|

# %%
paramnames = [('H0','H_{0}'),('Om', r'\Omega_{m0}'),('rd','r_d (Mpc)'),('L',r'L'),('Ldof',r'L/Dof'),('p','p'),('Omega_Lambda', r'\Omega_{\Lambda0}')]
outputCCBAODESSN5YR.make_paramnames_files(paramnames)

posteriorCCBAODESSN5YR = outputCCBAODESSN5YR.posterior
# Out:
# WARNING:root:outlier fraction 0.18269230769230768
# chains/CC + BAO + DES SN5YR.txt
# Removed no burn in

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAODESSN5YR], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['darkblue','red','purple'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2 + DES SN5YR'],title_limit=1)
g.export("fig_e.pdf")
# Out:
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.8  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAO,posteriorCCBAOPP,posteriorCCBAOUnion3,posteriorCCBAODESSN5YR], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['royalblue', 'orangered', 'darkviolet', 'darkblue'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2', r'CC + DESI DR2 + PP', r'CC + DESI DR2 + Union3', r'CC + DESI DR2 + DES SN5YR'])
g.export("fig_f.pdf")
# Out:
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
def get_constraints(samples):
    for i, mean in enumerate(samples.getMeans()):
        upper = samples.confidence(i, upper=True, limfrac=0.05)
        #print("\nupper limit 95 C.L. = %f" % upper)
        lower = samples.confidence(i, upper=False, limfrac=0.05)
        #print("lower limit 95 C.L. = %f" % lower)
        print("%s = %f +/- %f +/- %f" % (samples.parLabel(i),\

        mean, mean - samples.confidence(i, limfrac=0.16),\
        mean - samples.confidence(i, limfrac=0.025)) )
    return
for i in ['CCBAODESSN5YR']:
    print(i)
    get_constraints(eval("posterior"+i))
# Out:
# CCBAODESSN5YR
# H_{0} = 67.943297 +/- 2.769710 +/- 5.971826
# \Omega_{m0} = 0.310120 +/- 0.005588 +/- 0.011272
# r_d (Mpc) = 148.278982 +/- 6.045745 +/- 11.695221
# L = 1662.253535 +/- 1.125356 +/- 1.396978
# L/Dof = 0.896577 +/- 0.000607 +/- 0.000753
# p = 0.999428 +/- 0.000041 +/- 0.000121
# \Omega_{\Lambda0} = 0.689880 +/- 0.005358 +/- 0.010229

# %%
outputCCBAODESSN5YR
# Out:
# Global evidence:
# log(Z)    -1672.141134 +/-  0.322200
#
# Local evidences:
# log(Z_1)     -2250.745036 +/-  0.759390
# log(Z_2)     -1719.414130 +/-  0.851210
# log(Z_3)     -1688.059087 +/-  0.679264
# log(Z_4)     -1680.403923 +/-  0.549023
# log(Z_5)     -1679.180135 +/-  0.449941
# log(Z_6)     -1678.179822 +/-  0.496562
# log(Z_7)     -1675.781351 +/-  0.553602
# log(Z_8)     -1675.366887 +/-  0.395980
# log(Z_9)     -1675.205906 +/-  0.414222
# log(Z_10)    -1674.793974 +/-  0.402413
# log(Z_11)    -1674.252749 +/-  0.397397
# log(Z_12)    -1674.740619 +/-  0.401775
# log(Z_13)    -1675.097290 +/-  0.408625
# log(Z_14)    -1674.586220 +/-  0.400336
# log(Z_15)    -1676.623760 +/-  0.425245
# log(Z_16)    -1675.831606 +/-  0.412684
# log(Z_17)    -1674.032987 +/-  0.403872
# log(Z_18)    -1673.483497 +/-  0.402842
#
# Run-time information:
# ncluster          18
# nposterior      1890
# nequals          158
# ndead           1890
# nlive              0
# nlike         187840
# <nlike>        [0.0]
#
# Parameter estimates:
# H0            H_{0}                6.799E+01 +/- 2.955E+00
# Om            \Omega_{m0}          3.098E-01 +/- 5.853E-03
# rd            r_d (Mpc)            1.482E+02 +/- 6.497E+00
# L             L                    1.662E+03 +/- 1.280E+00
# Ldof          L/Dof                8.966E-01 +/- 6.907E-04
# p             p                    9.994E-01 +/- 4.800E-05
# Omega_Lambda  \Omega_{\Lambda0}    6.902E-01 +/- 5.853E-03
